# %%
import pandas as pd
import seaborn as sns
import tabulate
import numpy as np

# %%
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)

# %%
from IPython.core.display import display, HTML

display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# /tmp/ipykernel_2359140/4065668965.py:1: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML
# <style>.container { width:100% !important; }</style>

# %%
# %load_ext jupyter_black
# Out:
#                 <script type="application/javascript" id="jupyter_black">
#                 (function() {
#                     if (window.IPython === undefined) {
#                         return
#                     }
#                     var msg = "WARNING: it looks like you might have loaded " +
#                         "jupyter_black in a non-lab notebook with " +
#                         "`is_lab=True`. Please double check, and if " +
#                         "loading with `%load_ext` please review the README!"
#                     console.log(msg)
#                     alert(msg)
#                 })()
#                 </script>

# %%
FN = "Plants datasets - Sheet1.csv'"
FN = "Plants datasets.xlsx"
# ds = pd.read_csv("./plants-dataset-spreadsheet.csv")
# ds = pd.read_csv(FN)
ds = pd.read_excel(FN, sheet_name="Tidy")

# %%
ds
# Out:
#                                              name  \
# 0                                   Pl@ntNet-300k
# 1                           Pl@ntNet observations
# 2   Pl@ntNet automatically identified occurrences
# 3                                        Flora-On
# 4                                        iNat2017
# 5                                        iNat2018
# 6                                        iNat2019
# 7                                        iNat2021
# 8                                iNaturalist-300k
# 9         iNaturalist Research-grade Observations
# 10                                    iNaturalist
# 11                        Plant Seedlings Dataset
# 12                Open Plant Phenotyping Database
# 13                                Flora Incognita
# 14                                  PlantCLEF2016
# 15                          PlantCLEF2017-trusted
# 16                    ExpertLifeCLEF 2018-trusted
# 17                                  PlantCLEF2019
# 18                                  PlantCLEF2020
# 19                                  PlantCLEF2021
# 20                                  PlantCLEF2022
# 21                          PlantCLEF2022-trusted
# 22                                         Flavia
# 23                                          Folia
# 24                                   Swedish leaf
# 25                                   Plantvillage
# 26                                       UCI Leaf
# 27                                      Leaf snap
# 28                                   Dillen et al
# 29                                  Lorieul et al
# 30                                  Herbarium 255
# 31                                   Herbarium 1K
# 32                                 Herbarium 2019
# 33                                 Herbarium 2020
# 34                                 Herbarium 2021
#
#                               short  \
# 0                     Pl@ntNet-300k
# 1             Pl@ntNet observations
# 2       Pl@ntNet autom. ident. occ.
# 3                          Flora-On
# 4                          iNat2017
# 5                          iNat2018
# 6                          iNat2019
# 7                          iNat2021
# 8                  iNaturalist-300k
# 9               iNat Research-grade
# 10                      iNaturalist
# 11          Plant Seedlings Dataset
# 12  Open Plant Phenotyping Database
# 13                  Flora Incognita
# 14                    PlantCLEF2016
# 15                  PlantCLEF2017-t
# 16            ExpertLifeCLEF 2018-t
# 17                    PlantCLEF2019
# 18                    PlantCLEF2020
# 19                    PlantCLEF2021
# 20                    PlantCLEF2022
# 21                  PlantCLEF2022-t
# 22                           Flavia
# 23                            Folia
# 24                     Swedish leaf
# 25                     Plantvillage
# 26                         UCI Leaf
# 27                        Leaf snap
# 28                     Dillen et al
# 29                    Lorieul et al
# 30                    Herbarium 255
# 31                     Herbarium 1K
# 32                   Herbarium 2019
# 33                   Herbarium 2020
# 34                   Herbarium 2021
#
#                                           doi  \
# 0      https://doi.org/10.5281/zenodo.5645731
# 1                          DOI10.15468/gtebaa
# 2             https://doi.org/10.15468/mma2ec
# 3                                         NaN
# 4   https://doi.org/10.48550/arXiv.1707.06642
# 5                                         NaN
# 6                                         NaN
# 7                                         NaN
# 8                                         NaN
# 9                          DOI10.15468/ab3s5x
# 10                                        NaN
# 11  https://doi.org/10.48550/arXiv.1711.05458
# 12         https://doi.org/10.3390/rs12081246
# 13                                        NaN
# 14                                        NaN
# 15                                        NaN
# 16                                        NaN
# 17                                        NaN
# 18                                        NaN
# 19                                        NaN
# 20                                        NaN
# 21                                        NaN
# 22                                        NaN
# 23   https://doi.org/10.48550/arXiv.1110.1513
# 24                                        NaN
# 25                                        NaN
# 26                                        NaN
# 27                                        NaN
# 28                                        NaN
# 29                                        NaN
# 30                                        NaN
# 31                                        NaN
# 32                                        NaN
# 33                                        NaN
# 34                           arXiv:2105.13808
#
#                                                  link  is_available  \
# 0   https://zenodo.org/record/5645731, https://git...           1.0
# 1   https://www.gbif.org/dataset/7a3679ef-5582-4aa...           1.0
# 2                     https://doi.org/10.15468/mma2ec           1.0
# 3                                https://flora-on.pt/           NaN
# 4   https://github.com/visipedia/inat_comp/tree/ma...           1.0
# 5   https://github.com/visipedia/inat_comp/tree/ma...           1.0
# 6   https://github.com/visipedia/inat_comp/tree/ma...           1.0
# 7   https://github.com/visipedia/inat_comp/tree/ma...           1.0
# 8                                                 NaN           1.0
# 9   https://www.gbif.org/occurrence/charts?dataset...           1.0
# 10  https://www.inaturalist.org/taxa/47126-Plantae...           1.0
# 11  https://vision.eng.au.dk/plant-seedlings-dataset/           1.0
# 12  https://vision.eng.au.dk/open-plant-phenotypin...           1.0
# 13                                                NaN           0.0
# 14      https://www.imageclef.org/lifeclef/2016/plant           1.0
# 15      https://www.imageclef.org/lifeclef/2017/plant           1.0
# 16                 https://www.imageclef.org/node/231           1.0
# 17            https://www.imageclef.org/PlantCLEF2019           1.0
# 18            https://www.imageclef.org/PlantCLEF2020           1.0
# 19            https://www.imageclef.org/PlantCLEF2021           0.0
# 20            https://www.imageclef.org/PlantCLEF2022           0.0
# 21            https://www.imageclef.org/PlantCLEF2022           0.0
# 22                    https://flavia.sourceforge.ne'/           1.0
# 23                                                NaN           1.0
# 24                                                NaN           NaN
# 25    https://data.mendeley.com/datasets/tywbtsjrjv/1           NaN
# 26                                                NaN           1.0
# 27                                                NaN           NaN
# 28                                                NaN           NaN
# 29                                                NaN           NaN
# 30                                                NaN           NaN
# 31                                                NaN           NaN
# 32                                                NaN           NaN
# 33                                                NaN           NaN
# 34  https://www.kaggle.com/c/herbarium-2021-fgvc8/...           1.0
#
#    aquisition_protocol  is_composed  num_images  num_images_splits_sum  \
# 0                field          0.0    306146.0                   True
# 1                field          0.0   1714213.0                   True
# 2                field          0.0  12142287.0                   True
# 3                  NaN          NaN         NaN                   True
# 4                field          0.0    196613.0                   True
# 5                field          0.0    127551.0                   True
# 6                field          0.0         NaN                  False
# 7                field          0.0   1191412.0                   True
# 8                field          0.0    526584.0                   True
# 9                field          0.0  24211423.0                   True
# 10               field          0.0  57480960.0                   True
# 11                 lab          0.0      4750.0                   True
# 12                 lab          0.0      7590.0                   True
# 13               mixed          0.0   1000000.0                  False
# 14               field          1.0    115788.0                   True
# 15              field?          1.0    345714.0                   True
# 16               field          1.0    327436.0                   True
# 17           field,web          1.0    437225.0                   True
# 18           lab,field          1.0    330772.0                   True
# 19           lab,field          1.0    330772.0                   True
# 20            misc,web          1.0   4013695.0                   True
# 21            misc,web          1.0   2942068.0                   True
# 22                 lab          0.0      1907.0                  False
# 23                 lab          0.0         NaN                   True
# 24                 lab          NaN      1125.0                  False
# 25                 lab          NaN     54306.0                  False
# 26                 lab          NaN       443.0                  False
# 27                 lab          NaN      2130.0                  False
# 28                 lab          NaN      1900.0                  False
# 29                 lab          NaN    163233.0                  False
# 30                 lab          NaN     11071.0                  False
# 31                 lab          NaN    253733.0                  False
# 32                 lab          NaN     46000.0                  False
# 33                 lab          NaN   1170000.0                  False
# 34                 lab          1.0   2500779.0                   True
#
#       training  validation      test  num_classes  num_images_full  \
# 0     243916.0     31118.0   31112.0       1081.0             -1.0
# 1    1714213.0         0.0       0.0      15490.0             -1.0
# 2   12142287.0         NaN       NaN      12572.0             -1.0
# 3          NaN         NaN       NaN          NaN              NaN
# 4     158407.0     38206.0       0.0       2101.0         675170.0
# 5     118800.0      8751.0       0.0       2917.0         461939.0
# 6          NaN         NaN       NaN          NaN         268243.0
# 7    1148702.0     42710.0       0.0       4271.0        2786843.0
# 8     421294.0     52726.0   52564.0        991.0             -1.0
# 9   24211423.0         0.0       0.0     113660.0       62664638.0
# 10  57480960.0         0.0       0.0     147776.0      140663548.0
# 11      4750.0         0.0       0.0         12.0             -1.0
# 12      7590.0         0.0       0.0         47.0             -1.0
# 13         NaN         NaN       NaN       4800.0             -1.0
# 14    113205.0         0.0    2583.0       1000.0             -1.0
# 15    320544.0         0.0   25170.0      10000.0             -1.0
# 16    320544.0         0.0    6892.0      10000.0             -1.0
# 17    434251.0         0.0    2974.0      10000.0             -1.0
# 18    327586.0         0.0    3186.0        997.0             -1.0
# 19    321270.0      6316.0    3186.0        997.0             -1.0
# 20   3958388.0         0.0   55307.0      80000.0             -1.0
# 21   2886761.0         0.0   55307.0      80000.0             -1.0
# 22         NaN         NaN       NaN         32.0             -1.0
# 23         NaN         NaN       NaN         50.0             -1.0
# 24         NaN         NaN       NaN         15.0             -1.0
# 25         NaN         NaN       NaN         38.0             -1.0
# 26         NaN         NaN       NaN         40.0             -1.0
# 27         NaN         NaN       NaN         52.0             -1.0
# 28         NaN         NaN       NaN       1580.0             -1.0
# 29         NaN         NaN       NaN       7782.0             -1.0
# 30         NaN         NaN       NaN        255.0             -1.0
# 31         NaN         NaN       NaN       1204.0             -1.0
# 32         NaN         NaN       NaN        680.0             -1.0
# 33         NaN         NaN       NaN      32000.0             -1.0
# 34   2257759.0         0.0  243020.0      64500.0             -1.0
#
#     num_classes_full                                additional_metadata  \
# 0               -1.0                                              organ
# 1               -1.0                                         GBIF_a_lot
# 2               -1.0                                                NaN
# 3                NaN                                                NaN
# 4             5089.0  bbox?,kingdom,GBIF,latitude,longitude,date,use...
# 5             8142.0  latitude,longitude,date, kingdom, phylum, clas...
# 6             1010.0  date, kingdom, phylum, class, order, family, g...
# 7            10000.0  latitude,longitude,location_uncertainty,date, ...
# 8               -1.0                                           taxonomy
# 9           332864.0  latitude,longitude,location_uncertainty,date, ...
# 10          429145.0  latitude?,longitude?,location_uncertainty?,dat...
# 11              -1.0                                      segmentation?
# 12              -1.0              growth_condition,bbox,box_id,trial_id
# 13              -1.0                                            6_views
# 14              -1.0                                        plant_organ
# 15              -1.0                                                NaN
# 16              -1.0                                   plant_organ,TODO
# 17              -1.0                                                NaN
# 18              -1.0                                           taxonomy
# 19              -1.0  growth_form,habitat,plant_lifeform,trophic_gui...
# 20              -1.0                                           taxonomy
# 21              -1.0                                           taxonomy
# 22              -1.0                                                NaN
# 23              -1.0                                                NaN
# 24              -1.0                                                NaN
# 25              -1.0                                           diseased
# 26              -1.0                                                NaN
# 27              -1.0                                                NaN
# 28              -1.0                                                NaN
# 29              -1.0                                                NaN
# 30              -1.0                                                NaN
# 31              -1.0                                                NaN
# 32              -1.0                                                NaN
# 33              -1.0                                                NaN
# 34              -1.0  date,license,region_id,name,family,order,insti...
#
#                type                                      super_classes  \
# 0             mixed                                             plants
# 1             mixed                                             plants
# 2             mixed                                                NaN
# 3               NaN                                                NaN
# 4             mixed  Plantae,Insecta,Aves,Reptilia,Mammalia,Fungi,A...
# 5             mixed  Plantae, Insecta, Aves, Actinopterygii, Fungi,...
# 6             mixed                                                NaN
# 7             mixed  Plants, Insects, Birds, Fungi, Reptiles, Mamma...
# 8             mixed                                                NaN
# 9             mixed  Animalia, Archaea, Bacteria, Chromista, Fungi,...
# 10            mixed  Animalia, Archaea, Bacteria, Chromista, Fungi,...
# 11     pic_from_top                                             plants
# 12     pic_from_top                                             plants
# 13            mixed                                             plants
# 14            mixed                                             plants
# 15            mixed                                             plants
# 16            mixed                                             plants
# 17            mixed                                             plants
# 18  herbarium,mixed                                             plants
# 19  herbarium,mixed                                             plants
# 20            mixed                                             plants
# 21            mixed                                             plants
# 22             leaf                                             plants
# 23             leaf                                             plants
# 24             leaf                                             plants
# 25             leaf                                             plants
# 26             leaf                                             plants
# 27             leaf                                             plants
# 28        herbarium                                             plants
# 29        herbarium                                             plants
# 30        herbarium                                             plants
# 31        herbarium                                             plants
# 32        herbarium                                             plants
# 33        herbarium                                             plants
# 34        herbarium                                             plants
#
#            dataset_parts                        is_split class_imbalance  \
# 0                    0.0                  train,val,test             1.0
# 1                    0.0                             0.0               ?
# 2                    0.0                             0.0             1.0
# 3                    NaN                             NaN             NaN
# 4                    0.0                 train,val,test?             1.0
# 5                    0.0                 train,val,test?             1.0
# 6                    0.0                 train,val,test?             1.0
# 7                    0.0                 train,val,test?             1.0
# 8                    NaN                 train,val,test?             1.0
# 9                    0.0                             0.0             1.0
# 10                   0.0                             0.0             1.0
# 11                   0.0                             0.0             0.0
# 12                   0.0                             0.0             NaN
# 13                   0.0                             NaN             NaN
# 14              plantnet                      train,test             NaN
# 15          eol,plantnet              train-trusted,test             NaN
# 16                   eol              train-trusted,test             1.0
# 17                   eol              train-trusted,test             NaN
# 18  eol,plantnet,idigbio           train,validation,test             NaN
# 19  eol,plantnet,idigbio                      train,test             1.0
# 20              gbif,eol  train-trusted, train-web, test             NaN
# 21              gbif,eol             train-trusted, test             NaN
# 22                   0.0                             NaN             NaN
# 23                   0.0                             NaN             NaN
# 24                   0.0                             NaN             NaN
# 25                   0.0                             NaN             NaN
# 26                   0.0                             NaN             NaN
# 27                   0.0                             NaN             NaN
# 28                   NaN                             NaN             NaN
# 29                   NaN                             NaN             NaN
# 30                   NaN                             NaN             NaN
# 31                   NaN                             NaN             NaN
# 32                   NaN                             NaN             NaN
# 33                   NaN                             NaN             NaN
# 34                   0.0                      train,test             1.0
#
#        generation_type                                            license  \
# 0       user-generated                                          CC-BY-4.0
# 1       user-generated                                          CC-BY-4.0
# 2       user-generated                                                NaN
# 3                  NaN                                          CC-BY-4.0
# 4       user-generated  custom:https://github.com/visipedia/inat_comp/...
# 5       user-generated                                             custom
# 6       user-generated                                             custom
# 7       user-generated                                             custom
# 8       user-generated                                CC-0,CC-BY,CC-BY-NC
# 9       user-generated                                CC-0,CC-BY,CC-BY-NC
# 10      user-generated                                             custom
# 11                 lab                                           CC-BY-SA
# 12                 lab                                        CC-BY-NC-SA
# 13      user-generated                                                NaN
# 14      user-generated                                                NaN
# 15               mixed                                                NaN
# 16               mixed                                                NaN
# 17               mixed                                                NaN
# 18  lab,user-generated                                                NaN
# 19  lab,user-generated                                                NaN
# 20  lab,user-generated                                                NaN
# 21  lab,user-generated                                                NaN
# 22                 lab                                                NaN
# 23                 lab                                                NaN
# 24                 lab                                                NaN
# 25                 lab                                                NaN
# 26                 lab                                                NaN
# 27                 lab                                                NaN
# 28                 NaN                                                NaN
# 29                 NaN                                                NaN
# 30                 lab                                                NaN
# 31                 lab                                                NaN
# 32                 lab                                                NaN
# 33                 lab                                                NaN
# 34                 lab                        CC-0,CC-BY-SA-2.0,CC-BY-4.0
#
#     baseline_available  constantly_updated  is_standardized  DONE  IMPORTANT  \
# 0                  1.0                 0.0              0.0   1.0        5.0
# 1                  0.0                 1.0              0.0   1.0        3.0
# 2                  0.0                 1.0              0.0   1.0        3.0
# 3                  0.0                 1.0              NaN   0.0        0.0
# 4                  1.0                 0.0              0.0   1.0        2.0
# 5                  0.0                 0.0              0.0   1.0        2.0
# 6                  0.0                 0.0              0.0   0.0        2.0
# 7                  0.0                 0.0              0.0   1.0        2.0
# 8                  1.0                 0.0              0.0   1.0        5.0
# 9                  0.0                 1.0              0.0   1.0        2.0
# 10                 0.0                 1.0              0.0   1.0        1.0
# 11                 0.0                 0.0              1.0   1.0        1.0
# 12                 1.0                 0.0              1.0   1.0        0.0
# 13                 NaN                 NaN              0.0   0.0        3.0
# 14                 1.0                 0.0              0.0   1.0        3.0
# 15                 1.0                 0.0              0.0   1.0        3.0
# 16                 1.0                 0.0              0.0   1.0        3.0
# 17                 1.0                 0.0              0.0   1.0        3.0
# 18                 1.0                 0.0              2.0   1.0        2.0
# 19                 1.0                 0.0              2.0   1.0        2.0
# 20                 1.0                 0.0              2.0   1.0        2.0
# 21                 1.0                 0.0              2.0   1.0        2.0
# 22                 1.0                 0.0              0.0   1.0        2.0
# 23                 NaN                 0.0              1.0   1.0        1.0
# 24                 1.0                 0.0              1.0   NaN        1.0
# 25                 1.0                 0.0              1.0   NaN        1.0
# 26                 NaN                 NaN              1.0   NaN        1.0
# 27                 1.0                 0.0              1.0   NaN        1.0
# 28                 NaN                 0.0              1.0   NaN        NaN
# 29                 NaN                 0.0              1.0   NaN        NaN
# 30                 NaN                 0.0              1.0   NaN        NaN
# 31                 NaN                 0.0              1.0   NaN        NaN
# 32                 NaN                 0.0              1.0   NaN        NaN
# 33                 NaN                 0.0              1.0   NaN        NaN
# 34                 1.0                 0.0              1.0   1.0        3.0
#
#                                              comments  \
# 0                                                 NaN
# 1                     the big dataset with everything
# 2                                                 NaN
# 3                                                 NaN
# 4   2017, has plants and other things; train/val i...
# 5                                                 NaN
# 6   REMAINING: look at how many plants there are a...
# 7                          location data can be null;
# 8                                      our dataset ^^
# 9             the 'best' pics from the iNaturalist ds
# 10                                 all of iNaturalist
# 11  ~960 plants, 4750 indiv. pictures in diff grow...
# 12  " 7,590 RGB images with 315,038 plant objects,...
# 13  a lot of papers, conflicting data, no clean re...
# 14                                                NaN
# 15  From https://www.frontiersin.org/articles/10.3...
# 16                              Only 'trusted' images
# 17           It has also train-google and train-bing!
# 18                                                NaN
# 19  321270 herb sheets, 6316 field photos, 354 obs...
# 20  ACTUALLY it has three datasets, for train ther...
# 21  This is only the 'trusted' train+test images, ...
# 22     taking stats from 10.1016/j.compag.2019.01.041
# 23                  some conflicting info re #classes
# 24     taking stats from 10.1016/j.compag.2019.01.042
# 25     taking stats from 10.1016/j.compag.2019.01.043
# 26                                                NaN
# 27  Taking stats from https://link.springer.com/ar...
# 28  Taken from table in half-world herbarium paper...
# 29  Taken from table in half-world herbarium paper...
# 30  Taken from table in half-world herbarium paper...
# 31  Taken from table in half-world herbarium paper...
# 32  Taken from table in half-world herbarium paper...
# 33  Taken from table in half-world herbarium paper...
# 34  80/20 train/test split; test split has differe...
#
#                                            TODO
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# 5                                           NaN
# 6                                           NaN
# 7                                           NaN
# 8                                           NaN
# 9                                           NaN
# 10                                          NaN
# 11                                          NaN
# 12                                          NaN
# 13                                          NaN
# 14                                          NaN
# 15                                Add untrusted
# 16                      Add untrusted; metadata
# 17  Add  train-[goolge/bing] web part+ metadtaa
# 18                                          NaN
# 19                                          NaN
# 20                                          NaN
# 21                                          NaN
# 22                                          NaN
# 23                                          NaN
# 24                                          NaN
# 25                                          NaN
# 26                                          NaN
# 27              Fill out everything from source
# 28              Fill out everything from source
# 29              Fill out everything from source
# 30              Fill out everything from source
# 31              Fill out everything from source
# 32              Fill out everything from source
# 33              Fill out everything from source
# 34                                          NaN

# %% [raw]
# # Manually fix plant seedlings dataset
# ds.loc[9, "num_images"] = 4750
# # Flora incognita
#
# # I'll extrapolate something for the purpose of the plot
# ds.loc[11, "num_images"] = 800000
# ds.loc[11, "num_classes"] = 16000
# ds.loc[11, "aquisition_protocol"] = "field"
# ds.loc[11, "type"] = "mixed"
#
#
# ds

# %%
# Flora incognita - nothing known
# ds.drop(index=11, inplace=True)

# %%
BIN_COLS = [
    "is_available",
    "is_composed",
    "baseline_available",
    "constantly_updated",
]  # , "is_split"]
NUM_COLS = [
    "num_images",
    "training",
    "validation",
    "test",
    "num_classes",
    "num_images_full",
    "num_classes_full",
    "IMPORTANT",
]

# %%
ds[BIN_COLS] = ds[BIN_COLS].astype(bool)
ds[NUM_COLS] = ds[NUM_COLS].astype(int, errors="ignore")
ds["not_train"] = ds["test"] + ds["validation"]
ds["is_split"] = ds["not_train"].astype(bool)
ds
# Out:
#                                              name  \
# 0                                   Pl@ntNet-300k
# 1                           Pl@ntNet observations
# 2   Pl@ntNet automatically identified occurrences
# 3                                        Flora-On
# 4                                        iNat2017
# 5                                        iNat2018
# 6                                        iNat2019
# 7                                        iNat2021
# 8                                iNaturalist-300k
# 9         iNaturalist Research-grade Observations
# 10                                    iNaturalist
# 11                        Plant Seedlings Dataset
# 12                Open Plant Phenotyping Database
# 13                                Flora Incognita
# 14                                  PlantCLEF2016
# 15                          PlantCLEF2017-trusted
# 16                    ExpertLifeCLEF 2018-trusted
# 17                                  PlantCLEF2019
# 18                                  PlantCLEF2020
# 19                                  PlantCLEF2021
# 20                                  PlantCLEF2022
# 21                          PlantCLEF2022-trusted
# 22                                         Flavia
# 23                                          Folia
# 24                                   Swedish leaf
# 25                                   Plantvillage
# 26                                       UCI Leaf
# 27                                      Leaf snap
# 28                                   Dillen et al
# 29                                  Lorieul et al
# 30                                  Herbarium 255
# 31                                   Herbarium 1K
# 32                                 Herbarium 2019
# 33                                 Herbarium 2020
# 34                                 Herbarium 2021
#
#                               short  \
# 0                     Pl@ntNet-300k
# 1             Pl@ntNet observations
# 2       Pl@ntNet autom. ident. occ.
# 3                          Flora-On
# 4                          iNat2017
# 5                          iNat2018
# 6                          iNat2019
# 7                          iNat2021
# 8                  iNaturalist-300k
# 9               iNat Research-grade
# 10                      iNaturalist
# 11          Plant Seedlings Dataset
# 12  Open Plant Phenotyping Database
# 13                  Flora Incognita
# 14                    PlantCLEF2016
# 15                  PlantCLEF2017-t
# 16            ExpertLifeCLEF 2018-t
# 17                    PlantCLEF2019
# 18                    PlantCLEF2020
# 19                    PlantCLEF2021
# 20                    PlantCLEF2022
# 21                  PlantCLEF2022-t
# 22                           Flavia
# 23                            Folia
# 24                     Swedish leaf
# 25                     Plantvillage
# 26                         UCI Leaf
# 27                        Leaf snap
# 28                     Dillen et al
# 29                    Lorieul et al
# 30                    Herbarium 255
# 31                     Herbarium 1K
# 32                   Herbarium 2019
# 33                   Herbarium 2020
# 34                   Herbarium 2021
#
#                                           doi  \
# 0      https://doi.org/10.5281/zenodo.5645731
# 1                          DOI10.15468/gtebaa
# 2             https://doi.org/10.15468/mma2ec
# 3                                         NaN
# 4   https://doi.org/10.48550/arXiv.1707.06642
# 5                                         NaN
# 6                                         NaN
# 7                                         NaN
# 8                                         NaN
# 9                          DOI10.15468/ab3s5x
# 10                                        NaN
# 11  https://doi.org/10.48550/arXiv.1711.05458
# 12         https://doi.org/10.3390/rs12081246
# 13                                        NaN
# 14                                        NaN
# 15                                        NaN
# 16                                        NaN
# 17                                        NaN
# 18                                        NaN
# 19                                        NaN
# 20                                        NaN
# 21                                        NaN
# 22                                        NaN
# 23   https://doi.org/10.48550/arXiv.1110.1513
# 24                                        NaN
# 25                                        NaN
# 26                                        NaN
# 27                                        NaN
# 28                                        NaN
# 29                                        NaN
# 30                                        NaN
# 31                                        NaN
# 32                                        NaN
# 33                                        NaN
# 34                           arXiv:2105.13808
#
#                                                  link  is_available  \
# 0   https://zenodo.org/record/5645731, https://git...          True
# 1   https://www.gbif.org/dataset/7a3679ef-5582-4aa...          True
# 2                     https://doi.org/10.15468/mma2ec          True
# 3                                https://flora-on.pt/          True
# 4   https://github.com/visipedia/inat_comp/tree/ma...          True
# 5   https://github.com/visipedia/inat_comp/tree/ma...          True
# 6   https://github.com/visipedia/inat_comp/tree/ma...          True
# 7   https://github.com/visipedia/inat_comp/tree/ma...          True
# 8                                                 NaN          True
# 9   https://www.gbif.org/occurrence/charts?dataset...          True
# 10  https://www.inaturalist.org/taxa/47126-Plantae...          True
# 11  https://vision.eng.au.dk/plant-seedlings-dataset/          True
# 12  https://vision.eng.au.dk/open-plant-phenotypin...          True
# 13                                                NaN         False
# 14      https://www.imageclef.org/lifeclef/2016/plant          True
# 15      https://www.imageclef.org/lifeclef/2017/plant          True
# 16                 https://www.imageclef.org/node/231          True
# 17            https://www.imageclef.org/PlantCLEF2019          True
# 18            https://www.imageclef.org/PlantCLEF2020          True
# 19            https://www.imageclef.org/PlantCLEF2021         False
# 20            https://www.imageclef.org/PlantCLEF2022         False
# 21            https://www.imageclef.org/PlantCLEF2022         False
# 22                    https://flavia.sourceforge.ne'/          True
# 23                                                NaN          True
# 24                                                NaN          True
# 25    https://data.mendeley.com/datasets/tywbtsjrjv/1          True
# 26                                                NaN          True
# 27                                                NaN          True
# 28                                                NaN          True
# 29                                                NaN          True
# 30                                                NaN          True
# 31                                                NaN          True
# 32                                                NaN          True
# 33                                                NaN          True
# 34  https://www.kaggle.com/c/herbarium-2021-fgvc8/...          True
#
#    aquisition_protocol  is_composed  num_images  num_images_splits_sum  \
# 0                field        False    306146.0                   True
# 1                field        False   1714213.0                   True
# 2                field        False  12142287.0                   True
# 3                  NaN         True         NaN                   True
# 4                field        False    196613.0                   True
# 5                field        False    127551.0                   True
# 6                field        False         NaN                  False
# 7                field        False   1191412.0                   True
# 8                field        False    526584.0                   True
# 9                field        False  24211423.0                   True
# 10               field        False  57480960.0                   True
# 11                 lab        False      4750.0                   True
# 12                 lab        False      7590.0                   True
# 13               mixed        False   1000000.0                  False
# 14               field         True    115788.0                   True
# 15              field?         True    345714.0                   True
# 16               field         True    327436.0                   True
# 17           field,web         True    437225.0                   True
# 18           lab,field         True    330772.0                   True
# 19           lab,field         True    330772.0                   True
# 20            misc,web         True   4013695.0                   True
# 21            misc,web         True   2942068.0                   True
# 22                 lab        False      1907.0                  False
# 23                 lab        False         NaN                   True
# 24                 lab         True      1125.0                  False
# 25                 lab         True     54306.0                  False
# 26                 lab         True       443.0                  False
# 27                 lab         True      2130.0                  False
# 28                 lab         True      1900.0                  False
# 29                 lab         True    163233.0                  False
# 30                 lab         True     11071.0                  False
# 31                 lab         True    253733.0                  False
# 32                 lab         True     46000.0                  False
# 33                 lab         True   1170000.0                  False
# 34                 lab         True   2500779.0                   True
#
#       training  validation      test  num_classes  num_images_full  \
# 0     243916.0     31118.0   31112.0       1081.0             -1.0
# 1    1714213.0         0.0       0.0      15490.0             -1.0
# 2   12142287.0         NaN       NaN      12572.0             -1.0
# 3          NaN         NaN       NaN          NaN              NaN
# 4     158407.0     38206.0       0.0       2101.0         675170.0
# 5     118800.0      8751.0       0.0       2917.0         461939.0
# 6          NaN         NaN       NaN          NaN         268243.0
# 7    1148702.0     42710.0       0.0       4271.0        2786843.0
# 8     421294.0     52726.0   52564.0        991.0             -1.0
# 9   24211423.0         0.0       0.0     113660.0       62664638.0
# 10  57480960.0         0.0       0.0     147776.0      140663548.0
# 11      4750.0         0.0       0.0         12.0             -1.0
# 12      7590.0         0.0       0.0         47.0             -1.0
# 13         NaN         NaN       NaN       4800.0             -1.0
# 14    113205.0         0.0    2583.0       1000.0             -1.0
# 15    320544.0         0.0   25170.0      10000.0             -1.0
# 16    320544.0         0.0    6892.0      10000.0             -1.0
# 17    434251.0         0.0    2974.0      10000.0             -1.0
# 18    327586.0         0.0    3186.0        997.0             -1.0
# 19    321270.0      6316.0    3186.0        997.0             -1.0
# 20   3958388.0         0.0   55307.0      80000.0             -1.0
# 21   2886761.0         0.0   55307.0      80000.0             -1.0
# 22         NaN         NaN       NaN         32.0             -1.0
# 23         NaN         NaN       NaN         50.0             -1.0
# 24         NaN         NaN       NaN         15.0             -1.0
# 25         NaN         NaN       NaN         38.0             -1.0
# 26         NaN         NaN       NaN         40.0             -1.0
# 27         NaN         NaN       NaN         52.0             -1.0
# 28         NaN         NaN       NaN       1580.0             -1.0
# 29         NaN         NaN       NaN       7782.0             -1.0
# 30         NaN         NaN       NaN        255.0             -1.0
# 31         NaN         NaN       NaN       1204.0             -1.0
# 32         NaN         NaN       NaN        680.0             -1.0
# 33         NaN         NaN       NaN      32000.0             -1.0
# 34   2257759.0         0.0  243020.0      64500.0             -1.0
#
#     num_classes_full                                additional_metadata  \
# 0               -1.0                                              organ
# 1               -1.0                                         GBIF_a_lot
# 2               -1.0                                                NaN
# 3                NaN                                                NaN
# 4             5089.0  bbox?,kingdom,GBIF,latitude,longitude,date,use...
# 5             8142.0  latitude,longitude,date, kingdom, phylum, clas...
# 6             1010.0  date, kingdom, phylum, class, order, family, g...
# 7            10000.0  latitude,longitude,location_uncertainty,date, ...
# 8               -1.0                                           taxonomy
# 9           332864.0  latitude,longitude,location_uncertainty,date, ...
# 10          429145.0  latitude?,longitude?,location_uncertainty?,dat...
# 11              -1.0                                      segmentation?
# 12              -1.0              growth_condition,bbox,box_id,trial_id
# 13              -1.0                                            6_views
# 14              -1.0                                        plant_organ
# 15              -1.0                                                NaN
# 16              -1.0                                   plant_organ,TODO
# 17              -1.0                                                NaN
# 18              -1.0                                           taxonomy
# 19              -1.0  growth_form,habitat,plant_lifeform,trophic_gui...
# 20              -1.0                                           taxonomy
# 21              -1.0                                           taxonomy
# 22              -1.0                                                NaN
# 23              -1.0                                                NaN
# 24              -1.0                                                NaN
# 25              -1.0                                           diseased
# 26              -1.0                                                NaN
# 27              -1.0                                                NaN
# 28              -1.0                                                NaN
# 29              -1.0                                                NaN
# 30              -1.0                                                NaN
# 31              -1.0                                                NaN
# 32              -1.0                                                NaN
# 33              -1.0                                                NaN
# 34              -1.0  date,license,region_id,name,family,order,insti...
#
#                type                                      super_classes  \
# 0             mixed                                             plants
# 1             mixed                                             plants
# 2             mixed                                                NaN
# 3               NaN                                                NaN
# 4             mixed  Plantae,Insecta,Aves,Reptilia,Mammalia,Fungi,A...
# 5             mixed  Plantae, Insecta, Aves, Actinopterygii, Fungi,...
# 6             mixed                                                NaN
# 7             mixed  Plants, Insects, Birds, Fungi, Reptiles, Mamma...
# 8             mixed                                                NaN
# 9             mixed  Animalia, Archaea, Bacteria, Chromista, Fungi,...
# 10            mixed  Animalia, Archaea, Bacteria, Chromista, Fungi,...
# 11     pic_from_top                                             plants
# 12     pic_from_top                                             plants
# 13            mixed                                             plants
# 14            mixed                                             plants
# 15            mixed                                             plants
# 16            mixed                                             plants
# 17            mixed                                             plants
# 18  herbarium,mixed                                             plants
# 19  herbarium,mixed                                             plants
# 20            mixed                                             plants
# 21            mixed                                             plants
# 22             leaf                                             plants
# 23             leaf                                             plants
# 24             leaf                                             plants
# 25             leaf                                             plants
# 26             leaf                                             plants
# 27             leaf                                             plants
# 28        herbarium                                             plants
# 29        herbarium                                             plants
# 30        herbarium                                             plants
# 31        herbarium                                             plants
# 32        herbarium                                             plants
# 33        herbarium                                             plants
# 34        herbarium                                             plants
#
#            dataset_parts  is_split class_imbalance     generation_type  \
# 0                    0.0      True             1.0      user-generated
# 1                    0.0     False               ?      user-generated
# 2                    0.0      True             1.0      user-generated
# 3                    NaN      True             NaN                 NaN
# 4                    0.0      True             1.0      user-generated
# 5                    0.0      True             1.0      user-generated
# 6                    0.0      True             1.0      user-generated
# 7                    0.0      True             1.0      user-generated
# 8                    NaN      True             1.0      user-generated
# 9                    0.0     False             1.0      user-generated
# 10                   0.0     False             1.0      user-generated
# 11                   0.0     False             0.0                 lab
# 12                   0.0     False             NaN                 lab
# 13                   0.0      True             NaN      user-generated
# 14              plantnet      True             NaN      user-generated
# 15          eol,plantnet      True             NaN               mixed
# 16                   eol      True             1.0               mixed
# 17                   eol      True             NaN               mixed
# 18  eol,plantnet,idigbio      True             NaN  lab,user-generated
# 19  eol,plantnet,idigbio      True             1.0  lab,user-generated
# 20              gbif,eol      True             NaN  lab,user-generated
# 21              gbif,eol      True             NaN  lab,user-generated
# 22                   0.0      True             NaN                 lab
# 23                   0.0      True             NaN                 lab
# 24                   0.0      True             NaN                 lab
# 25                   0.0      True             NaN                 lab
# 26                   0.0      True             NaN                 lab
# 27                   0.0      True             NaN                 lab
# 28                   NaN      True             NaN                 NaN
# 29                   NaN      True             NaN                 NaN
# 30                   NaN      True             NaN                 lab
# 31                   NaN      True             NaN                 lab
# 32                   NaN      True             NaN                 lab
# 33                   NaN      True             NaN                 lab
# 34                   0.0      True             1.0                 lab
#
#                                               license  baseline_available  \
# 0                                           CC-BY-4.0                True
# 1                                           CC-BY-4.0               False
# 2                                                 NaN               False
# 3                                           CC-BY-4.0               False
# 4   custom:https://github.com/visipedia/inat_comp/...                True
# 5                                              custom               False
# 6                                              custom               False
# 7                                              custom               False
# 8                                 CC-0,CC-BY,CC-BY-NC                True
# 9                                 CC-0,CC-BY,CC-BY-NC               False
# 10                                             custom               False
# 11                                           CC-BY-SA               False
# 12                                        CC-BY-NC-SA                True
# 13                                                NaN                True
# 14                                                NaN                True
# 15                                                NaN                True
# 16                                                NaN                True
# 17                                                NaN                True
# 18                                                NaN                True
# 19                                                NaN                True
# 20                                                NaN                True
# 21                                                NaN                True
# 22                                                NaN                True
# 23                                                NaN                True
# 24                                                NaN                True
# 25                                                NaN                True
# 26                                                NaN                True
# 27                                                NaN                True
# 28                                                NaN                True
# 29                                                NaN                True
# 30                                                NaN                True
# 31                                                NaN                True
# 32                                                NaN                True
# 33                                                NaN                True
# 34                        CC-0,CC-BY-SA-2.0,CC-BY-4.0                True
#
#     constantly_updated  is_standardized  DONE  IMPORTANT  \
# 0                False              0.0   1.0        5.0
# 1                 True              0.0   1.0        3.0
# 2                 True              0.0   1.0        3.0
# 3                 True              NaN   0.0        0.0
# 4                False              0.0   1.0        2.0
# 5                False              0.0   1.0        2.0
# 6                False              0.0   0.0        2.0
# 7                False              0.0   1.0        2.0
# 8                False              0.0   1.0        5.0
# 9                 True              0.0   1.0        2.0
# 10                True              0.0   1.0        1.0
# 11               False              1.0   1.0        1.0
# 12               False              1.0   1.0        0.0
# 13                True              0.0   0.0        3.0
# 14               False              0.0   1.0        3.0
# 15               False              0.0   1.0        3.0
# 16               False              0.0   1.0        3.0
# 17               False              0.0   1.0        3.0
# 18               False              2.0   1.0        2.0
# 19               False              2.0   1.0        2.0
# 20               False              2.0   1.0        2.0
# 21               False              2.0   1.0        2.0
# 22               False              0.0   1.0        2.0
# 23               False              1.0   1.0        1.0
# 24               False              1.0   NaN        1.0
# 25               False              1.0   NaN        1.0
# 26                True              1.0   NaN        1.0
# 27               False              1.0   NaN        1.0
# 28               False              1.0   NaN        NaN
# 29               False              1.0   NaN        NaN
# 30               False              1.0   NaN        NaN
# 31               False              1.0   NaN        NaN
# 32               False              1.0   NaN        NaN
# 33               False              1.0   NaN        NaN
# 34               False              1.0   1.0        3.0
#
#                                              comments  \
# 0                                                 NaN
# 1                     the big dataset with everything
# 2                                                 NaN
# 3                                                 NaN
# 4   2017, has plants and other things; train/val i...
# 5                                                 NaN
# 6   REMAINING: look at how many plants there are a...
# 7                          location data can be null;
# 8                                      our dataset ^^
# 9             the 'best' pics from the iNaturalist ds
# 10                                 all of iNaturalist
# 11  ~960 plants, 4750 indiv. pictures in diff grow...
# 12  " 7,590 RGB images with 315,038 plant objects,...
# 13  a lot of papers, conflicting data, no clean re...
# 14                                                NaN
# 15  From https://www.frontiersin.org/articles/10.3...
# 16                              Only 'trusted' images
# 17           It has also train-google and train-bing!
# 18                                                NaN
# 19  321270 herb sheets, 6316 field photos, 354 obs...
# 20  ACTUALLY it has three datasets, for train ther...
# 21  This is only the 'trusted' train+test images, ...
# 22     taking stats from 10.1016/j.compag.2019.01.041
# 23                  some conflicting info re #classes
# 24     taking stats from 10.1016/j.compag.2019.01.042
# 25     taking stats from 10.1016/j.compag.2019.01.043
# 26                                                NaN
# 27  Taking stats from https://link.springer.com/ar...
# 28  Taken from table in half-world herbarium paper...
# 29  Taken from table in half-world herbarium paper...
# 30  Taken from table in half-world herbarium paper...
# 31  Taken from table in half-world herbarium paper...
# 32  Taken from table in half-world herbarium paper...
# 33  Taken from table in half-world herbarium paper...
# 34  80/20 train/test split; test split has differe...
#
#                                            TODO  not_train
# 0                                           NaN    62230.0
# 1                                           NaN        0.0
# 2                                           NaN        NaN
# 3                                           NaN        NaN
# 4                                           NaN    38206.0
# 5                                           NaN     8751.0
# 6                                           NaN        NaN
# 7                                           NaN    42710.0
# 8                                           NaN   105290.0
# 9                                           NaN        0.0
# 10                                          NaN        0.0
# 11                                          NaN        0.0
# 12                                          NaN        0.0
# 13                                          NaN        NaN
# 14                                          NaN     2583.0
# 15                                Add untrusted    25170.0
# 16                      Add untrusted; metadata     6892.0
# 17  Add  train-[goolge/bing] web part+ metadtaa     2974.0
# 18                                          NaN     3186.0
# 19                                          NaN     9502.0
# 20                                          NaN    55307.0
# 21                                          NaN    55307.0
# 22                                          NaN        NaN
# 23                                          NaN        NaN
# 24                                          NaN        NaN
# 25                                          NaN        NaN
# 26                                          NaN        NaN
# 27              Fill out everything from source        NaN
# 28              Fill out everything from source        NaN
# 29              Fill out everything from source        NaN
# 30              Fill out everything from source        NaN
# 31              Fill out everything from source        NaN
# 32              Fill out everything from source        NaN
# 33              Fill out everything from source        NaN
# 34                                          NaN   243020.0

# %%
MAP_STAND_DICT = {0.0: "Not standardized", 1.0: "Standardized", 2.0: "N/A"}
ds.loc[:, "is_standardized_parsed"] = ds.is_standardized.apply(
    lambda x: MAP_STAND_DICT.get(x, "None")
)
ds
# Out:
#                                              name  \
# 0                                   Pl@ntNet-300k
# 1                           Pl@ntNet observations
# 2   Pl@ntNet automatically identified occurrences
# 3                                        Flora-On
# 4                                        iNat2017
# 5                                        iNat2018
# 6                                        iNat2019
# 7                                        iNat2021
# 8                                iNaturalist-300k
# 9         iNaturalist Research-grade Observations
# 10                                    iNaturalist
# 11                        Plant Seedlings Dataset
# 12                Open Plant Phenotyping Database
# 13                                Flora Incognita
# 14                                  PlantCLEF2016
# 15                          PlantCLEF2017-trusted
# 16                    ExpertLifeCLEF 2018-trusted
# 17                                  PlantCLEF2019
# 18                                  PlantCLEF2020
# 19                                  PlantCLEF2021
# 20                                  PlantCLEF2022
# 21                          PlantCLEF2022-trusted
# 22                                         Flavia
# 23                                          Folia
# 24                                   Swedish leaf
# 25                                   Plantvillage
# 26                                       UCI Leaf
# 27                                      Leaf snap
# 28                                   Dillen et al
# 29                                  Lorieul et al
# 30                                  Herbarium 255
# 31                                   Herbarium 1K
# 32                                 Herbarium 2019
# 33                                 Herbarium 2020
# 34                                 Herbarium 2021
#
#                               short  \
# 0                     Pl@ntNet-300k
# 1             Pl@ntNet observations
# 2       Pl@ntNet autom. ident. occ.
# 3                          Flora-On
# 4                          iNat2017
# 5                          iNat2018
# 6                          iNat2019
# 7                          iNat2021
# 8                  iNaturalist-300k
# 9               iNat Research-grade
# 10                      iNaturalist
# 11          Plant Seedlings Dataset
# 12  Open Plant Phenotyping Database
# 13                  Flora Incognita
# 14                    PlantCLEF2016
# 15                  PlantCLEF2017-t
# 16            ExpertLifeCLEF 2018-t
# 17                    PlantCLEF2019
# 18                    PlantCLEF2020
# 19                    PlantCLEF2021
# 20                    PlantCLEF2022
# 21                  PlantCLEF2022-t
# 22                           Flavia
# 23                            Folia
# 24                     Swedish leaf
# 25                     Plantvillage
# 26                         UCI Leaf
# 27                        Leaf snap
# 28                     Dillen et al
# 29                    Lorieul et al
# 30                    Herbarium 255
# 31                     Herbarium 1K
# 32                   Herbarium 2019
# 33                   Herbarium 2020
# 34                   Herbarium 2021
#
#                                           doi  \
# 0      https://doi.org/10.5281/zenodo.5645731
# 1                          DOI10.15468/gtebaa
# 2             https://doi.org/10.15468/mma2ec
# 3                                         NaN
# 4   https://doi.org/10.48550/arXiv.1707.06642
# 5                                         NaN
# 6                                         NaN
# 7                                         NaN
# 8                                         NaN
# 9                          DOI10.15468/ab3s5x
# 10                                        NaN
# 11  https://doi.org/10.48550/arXiv.1711.05458
# 12         https://doi.org/10.3390/rs12081246
# 13                                        NaN
# 14                                        NaN
# 15                                        NaN
# 16                                        NaN
# 17                                        NaN
# 18                                        NaN
# 19                                        NaN
# 20                                        NaN
# 21                                        NaN
# 22                                        NaN
# 23   https://doi.org/10.48550/arXiv.1110.1513
# 24                                        NaN
# 25                                        NaN
# 26                                        NaN
# 27                                        NaN
# 28                                        NaN
# 29                                        NaN
# 30                                        NaN
# 31                                        NaN
# 32                                        NaN
# 33                                        NaN
# 34                           arXiv:2105.13808
#
#                                                  link  is_available  \
# 0   https://zenodo.org/record/5645731, https://git...          True
# 1   https://www.gbif.org/dataset/7a3679ef-5582-4aa...          True
# 2                     https://doi.org/10.15468/mma2ec          True
# 3                                https://flora-on.pt/          True
# 4   https://github.com/visipedia/inat_comp/tree/ma...          True
# 5   https://github.com/visipedia/inat_comp/tree/ma...          True
# 6   https://github.com/visipedia/inat_comp/tree/ma...          True
# 7   https://github.com/visipedia/inat_comp/tree/ma...          True
# 8                                                 NaN          True
# 9   https://www.gbif.org/occurrence/charts?dataset...          True
# 10  https://www.inaturalist.org/taxa/47126-Plantae...          True
# 11  https://vision.eng.au.dk/plant-seedlings-dataset/          True
# 12  https://vision.eng.au.dk/open-plant-phenotypin...          True
# 13                                                NaN         False
# 14      https://www.imageclef.org/lifeclef/2016/plant          True
# 15      https://www.imageclef.org/lifeclef/2017/plant          True
# 16                 https://www.imageclef.org/node/231          True
# 17            https://www.imageclef.org/PlantCLEF2019          True
# 18            https://www.imageclef.org/PlantCLEF2020          True
# 19            https://www.imageclef.org/PlantCLEF2021         False
# 20            https://www.imageclef.org/PlantCLEF2022         False
# 21            https://www.imageclef.org/PlantCLEF2022         False
# 22                    https://flavia.sourceforge.ne'/          True
# 23                                                NaN          True
# 24                                                NaN          True
# 25    https://data.mendeley.com/datasets/tywbtsjrjv/1          True
# 26                                                NaN          True
# 27                                                NaN          True
# 28                                                NaN          True
# 29                                                NaN          True
# 30                                                NaN          True
# 31                                                NaN          True
# 32                                                NaN          True
# 33                                                NaN          True
# 34  https://www.kaggle.com/c/herbarium-2021-fgvc8/...          True
#
#    aquisition_protocol  is_composed  num_images  num_images_splits_sum  \
# 0                field        False    306146.0                   True
# 1                field        False   1714213.0                   True
# 2                field        False  12142287.0                   True
# 3                  NaN         True         NaN                   True
# 4                field        False    196613.0                   True
# 5                field        False    127551.0                   True
# 6                field        False         NaN                  False
# 7                field        False   1191412.0                   True
# 8                field        False    526584.0                   True
# 9                field        False  24211423.0                   True
# 10               field        False  57480960.0                   True
# 11                 lab        False      4750.0                   True
# 12                 lab        False      7590.0                   True
# 13               mixed        False   1000000.0                  False
# 14               field         True    115788.0                   True
# 15              field?         True    345714.0                   True
# 16               field         True    327436.0                   True
# 17           field,web         True    437225.0                   True
# 18           lab,field         True    330772.0                   True
# 19           lab,field         True    330772.0                   True
# 20            misc,web         True   4013695.0                   True
# 21            misc,web         True   2942068.0                   True
# 22                 lab        False      1907.0                  False
# 23                 lab        False         NaN                   True
# 24                 lab         True      1125.0                  False
# 25                 lab         True     54306.0                  False
# 26                 lab         True       443.0                  False
# 27                 lab         True      2130.0                  False
# 28                 lab         True      1900.0                  False
# 29                 lab         True    163233.0                  False
# 30                 lab         True     11071.0                  False
# 31                 lab         True    253733.0                  False
# 32                 lab         True     46000.0                  False
# 33                 lab         True   1170000.0                  False
# 34                 lab         True   2500779.0                   True
#
#       training  validation      test  num_classes  num_images_full  \
# 0     243916.0     31118.0   31112.0       1081.0             -1.0
# 1    1714213.0         0.0       0.0      15490.0             -1.0
# 2   12142287.0         NaN       NaN      12572.0             -1.0
# 3          NaN         NaN       NaN          NaN              NaN
# 4     158407.0     38206.0       0.0       2101.0         675170.0
# 5     118800.0      8751.0       0.0       2917.0         461939.0
# 6          NaN         NaN       NaN          NaN         268243.0
# 7    1148702.0     42710.0       0.0       4271.0        2786843.0
# 8     421294.0     52726.0   52564.0        991.0             -1.0
# 9   24211423.0         0.0       0.0     113660.0       62664638.0
# 10  57480960.0         0.0       0.0     147776.0      140663548.0
# 11      4750.0         0.0       0.0         12.0             -1.0
# 12      7590.0         0.0       0.0         47.0             -1.0
# 13         NaN         NaN       NaN       4800.0             -1.0
# 14    113205.0         0.0    2583.0       1000.0             -1.0
# 15    320544.0         0.0   25170.0      10000.0             -1.0
# 16    320544.0         0.0    6892.0      10000.0             -1.0
# 17    434251.0         0.0    2974.0      10000.0             -1.0
# 18    327586.0         0.0    3186.0        997.0             -1.0
# 19    321270.0      6316.0    3186.0        997.0             -1.0
# 20   3958388.0         0.0   55307.0      80000.0             -1.0
# 21   2886761.0         0.0   55307.0      80000.0             -1.0
# 22         NaN         NaN       NaN         32.0             -1.0
# 23         NaN         NaN       NaN         50.0             -1.0
# 24         NaN         NaN       NaN         15.0             -1.0
# 25         NaN         NaN       NaN         38.0             -1.0
# 26         NaN         NaN       NaN         40.0             -1.0
# 27         NaN         NaN       NaN         52.0             -1.0
# 28         NaN         NaN       NaN       1580.0             -1.0
# 29         NaN         NaN       NaN       7782.0             -1.0
# 30         NaN         NaN       NaN        255.0             -1.0
# 31         NaN         NaN       NaN       1204.0             -1.0
# 32         NaN         NaN       NaN        680.0             -1.0
# 33         NaN         NaN       NaN      32000.0             -1.0
# 34   2257759.0         0.0  243020.0      64500.0             -1.0
#
#     num_classes_full                                additional_metadata  \
# 0               -1.0                                              organ
# 1               -1.0                                         GBIF_a_lot
# 2               -1.0                                                NaN
# 3                NaN                                                NaN
# 4             5089.0  bbox?,kingdom,GBIF,latitude,longitude,date,use...
# 5             8142.0  latitude,longitude,date, kingdom, phylum, clas...
# 6             1010.0  date, kingdom, phylum, class, order, family, g...
# 7            10000.0  latitude,longitude,location_uncertainty,date, ...
# 8               -1.0                                           taxonomy
# 9           332864.0  latitude,longitude,location_uncertainty,date, ...
# 10          429145.0  latitude?,longitude?,location_uncertainty?,dat...
# 11              -1.0                                      segmentation?
# 12              -1.0              growth_condition,bbox,box_id,trial_id
# 13              -1.0                                            6_views
# 14              -1.0                                        plant_organ
# 15              -1.0                                                NaN
# 16              -1.0                                   plant_organ,TODO
# 17              -1.0                                                NaN
# 18              -1.0                                           taxonomy
# 19              -1.0  growth_form,habitat,plant_lifeform,trophic_gui...
# 20              -1.0                                           taxonomy
# 21              -1.0                                           taxonomy
# 22              -1.0                                                NaN
# 23              -1.0                                                NaN
# 24              -1.0                                                NaN
# 25              -1.0                                           diseased
# 26              -1.0                                                NaN
# 27              -1.0                                                NaN
# 28              -1.0                                                NaN
# 29              -1.0                                                NaN
# 30              -1.0                                                NaN
# 31              -1.0                                                NaN
# 32              -1.0                                                NaN
# 33              -1.0                                                NaN
# 34              -1.0  date,license,region_id,name,family,order,insti...
#
#                type                                      super_classes  \
# 0             mixed                                             plants
# 1             mixed                                             plants
# 2             mixed                                                NaN
# 3               NaN                                                NaN
# 4             mixed  Plantae,Insecta,Aves,Reptilia,Mammalia,Fungi,A...
# 5             mixed  Plantae, Insecta, Aves, Actinopterygii, Fungi,...
# 6             mixed                                                NaN
# 7             mixed  Plants, Insects, Birds, Fungi, Reptiles, Mamma...
# 8             mixed                                                NaN
# 9             mixed  Animalia, Archaea, Bacteria, Chromista, Fungi,...
# 10            mixed  Animalia, Archaea, Bacteria, Chromista, Fungi,...
# 11     pic_from_top                                             plants
# 12     pic_from_top                                             plants
# 13            mixed                                             plants
# 14            mixed                                             plants
# 15            mixed                                             plants
# 16            mixed                                             plants
# 17            mixed                                             plants
# 18  herbarium,mixed                                             plants
# 19  herbarium,mixed                                             plants
# 20            mixed                                             plants
# 21            mixed                                             plants
# 22             leaf                                             plants
# 23             leaf                                             plants
# 24             leaf                                             plants
# 25             leaf                                             plants
# 26             leaf                                             plants
# 27             leaf                                             plants
# 28        herbarium                                             plants
# 29        herbarium                                             plants
# 30        herbarium                                             plants
# 31        herbarium                                             plants
# 32        herbarium                                             plants
# 33        herbarium                                             plants
# 34        herbarium                                             plants
#
#            dataset_parts  is_split class_imbalance     generation_type  \
# 0                    0.0      True             1.0      user-generated
# 1                    0.0     False               ?      user-generated
# 2                    0.0      True             1.0      user-generated
# 3                    NaN      True             NaN                 NaN
# 4                    0.0      True             1.0      user-generated
# 5                    0.0      True             1.0      user-generated
# 6                    0.0      True             1.0      user-generated
# 7                    0.0      True             1.0      user-generated
# 8                    NaN      True             1.0      user-generated
# 9                    0.0     False             1.0      user-generated
# 10                   0.0     False             1.0      user-generated
# 11                   0.0     False             0.0                 lab
# 12                   0.0     False             NaN                 lab
# 13                   0.0      True             NaN      user-generated
# 14              plantnet      True             NaN      user-generated
# 15          eol,plantnet      True             NaN               mixed
# 16                   eol      True             1.0               mixed
# 17                   eol      True             NaN               mixed
# 18  eol,plantnet,idigbio      True             NaN  lab,user-generated
# 19  eol,plantnet,idigbio      True             1.0  lab,user-generated
# 20              gbif,eol      True             NaN  lab,user-generated
# 21              gbif,eol      True             NaN  lab,user-generated
# 22                   0.0      True             NaN                 lab
# 23                   0.0      True             NaN                 lab
# 24                   0.0      True             NaN                 lab
# 25                   0.0      True             NaN                 lab
# 26                   0.0      True             NaN                 lab
# 27                   0.0      True             NaN                 lab
# 28                   NaN      True             NaN                 NaN
# 29                   NaN      True             NaN                 NaN
# 30                   NaN      True             NaN                 lab
# 31                   NaN      True             NaN                 lab
# 32                   NaN      True             NaN                 lab
# 33                   NaN      True             NaN                 lab
# 34                   0.0      True             1.0                 lab
#
#                                               license  baseline_available  \
# 0                                           CC-BY-4.0                True
# 1                                           CC-BY-4.0               False
# 2                                                 NaN               False
# 3                                           CC-BY-4.0               False
# 4   custom:https://github.com/visipedia/inat_comp/...                True
# 5                                              custom               False
# 6                                              custom               False
# 7                                              custom               False
# 8                                 CC-0,CC-BY,CC-BY-NC                True
# 9                                 CC-0,CC-BY,CC-BY-NC               False
# 10                                             custom               False
# 11                                           CC-BY-SA               False
# 12                                        CC-BY-NC-SA                True
# 13                                                NaN                True
# 14                                                NaN                True
# 15                                                NaN                True
# 16                                                NaN                True
# 17                                                NaN                True
# 18                                                NaN                True
# 19                                                NaN                True
# 20                                                NaN                True
# 21                                                NaN                True
# 22                                                NaN                True
# 23                                                NaN                True
# 24                                                NaN                True
# 25                                                NaN                True
# 26                                                NaN                True
# 27                                                NaN                True
# 28                                                NaN                True
# 29                                                NaN                True
# 30                                                NaN                True
# 31                                                NaN                True
# 32                                                NaN                True
# 33                                                NaN                True
# 34                        CC-0,CC-BY-SA-2.0,CC-BY-4.0                True
#
#     constantly_updated  is_standardized  DONE  IMPORTANT  \
# 0                False              0.0   1.0        5.0
# 1                 True              0.0   1.0        3.0
# 2                 True              0.0   1.0        3.0
# 3                 True              NaN   0.0        0.0
# 4                False              0.0   1.0        2.0
# 5                False              0.0   1.0        2.0
# 6                False              0.0   0.0        2.0
# 7                False              0.0   1.0        2.0
# 8                False              0.0   1.0        5.0
# 9                 True              0.0   1.0        2.0
# 10                True              0.0   1.0        1.0
# 11               False              1.0   1.0        1.0
# 12               False              1.0   1.0        0.0
# 13                True              0.0   0.0        3.0
# 14               False              0.0   1.0        3.0
# 15               False              0.0   1.0        3.0
# 16               False              0.0   1.0        3.0
# 17               False              0.0   1.0        3.0
# 18               False              2.0   1.0        2.0
# 19               False              2.0   1.0        2.0
# 20               False              2.0   1.0        2.0
# 21               False              2.0   1.0        2.0
# 22               False              0.0   1.0        2.0
# 23               False              1.0   1.0        1.0
# 24               False              1.0   NaN        1.0
# 25               False              1.0   NaN        1.0
# 26                True              1.0   NaN        1.0
# 27               False              1.0   NaN        1.0
# 28               False              1.0   NaN        NaN
# 29               False              1.0   NaN        NaN
# 30               False              1.0   NaN        NaN
# 31               False              1.0   NaN        NaN
# 32               False              1.0   NaN        NaN
# 33               False              1.0   NaN        NaN
# 34               False              1.0   1.0        3.0
#
#                                              comments  \
# 0                                                 NaN
# 1                     the big dataset with everything
# 2                                                 NaN
# 3                                                 NaN
# 4   2017, has plants and other things; train/val i...
# 5                                                 NaN
# 6   REMAINING: look at how many plants there are a...
# 7                          location data can be null;
# 8                                      our dataset ^^
# 9             the 'best' pics from the iNaturalist ds
# 10                                 all of iNaturalist
# 11  ~960 plants, 4750 indiv. pictures in diff grow...
# 12  " 7,590 RGB images with 315,038 plant objects,...
# 13  a lot of papers, conflicting data, no clean re...
# 14                                                NaN
# 15  From https://www.frontiersin.org/articles/10.3...
# 16                              Only 'trusted' images
# 17           It has also train-google and train-bing!
# 18                                                NaN
# 19  321270 herb sheets, 6316 field photos, 354 obs...
# 20  ACTUALLY it has three datasets, for train ther...
# 21  This is only the 'trusted' train+test images, ...
# 22     taking stats from 10.1016/j.compag.2019.01.041
# 23                  some conflicting info re #classes
# 24     taking stats from 10.1016/j.compag.2019.01.042
# 25     taking stats from 10.1016/j.compag.2019.01.043
# 26                                                NaN
# 27  Taking stats from https://link.springer.com/ar...
# 28  Taken from table in half-world herbarium paper...
# 29  Taken from table in half-world herbarium paper...
# 30  Taken from table in half-world herbarium paper...
# 31  Taken from table in half-world herbarium paper...
# 32  Taken from table in half-world herbarium paper...
# 33  Taken from table in half-world herbarium paper...
# 34  80/20 train/test split; test split has differe...
#
#                                            TODO  not_train  \
# 0                                           NaN    62230.0
# 1                                           NaN        0.0
# 2                                           NaN        NaN
# 3                                           NaN        NaN
# 4                                           NaN    38206.0
# 5                                           NaN     8751.0
# 6                                           NaN        NaN
# 7                                           NaN    42710.0
# 8                                           NaN   105290.0
# 9                                           NaN        0.0
# 10                                          NaN        0.0
# 11                                          NaN        0.0
# 12                                          NaN        0.0
# 13                                          NaN        NaN
# 14                                          NaN     2583.0
# 15                                Add untrusted    25170.0
# 16                      Add untrusted; metadata     6892.0
# 17  Add  train-[goolge/bing] web part+ metadtaa     2974.0
# 18                                          NaN     3186.0
# 19                                          NaN     9502.0
# 20                                          NaN    55307.0
# 21                                          NaN    55307.0
# 22                                          NaN        NaN
# 23                                          NaN        NaN
# 24                                          NaN        NaN
# 25                                          NaN        NaN
# 26                                          NaN        NaN
# 27              Fill out everything from source        NaN
# 28              Fill out everything from source        NaN
# 29              Fill out everything from source        NaN
# 30              Fill out everything from source        NaN
# 31              Fill out everything from source        NaN
# 32              Fill out everything from source        NaN
# 33              Fill out everything from source        NaN
# 34                                          NaN   243020.0
#
#    is_standardized_parsed
# 0        Not standardized
# 1        Not standardized
# 2        Not standardized
# 3                    None
# 4        Not standardized
# 5        Not standardized
# 6        Not standardized
# 7        Not standardized
# 8        Not standardized
# 9        Not standardized
# 10       Not standardized
# 11           Standardized
# 12           Standardized
# 13       Not standardized
# 14       Not standardized
# 15       Not standardized
# 16       Not standardized
# 17       Not standardized
# 18                    N/A
# 19                    N/A
# 20                    N/A
# 21                    N/A
# 22       Not standardized
# 23           Standardized
# 24           Standardized
# 25           Standardized
# 26           Standardized
# 27           Standardized
# 28           Standardized
# 29           Standardized
# 30           Standardized
# 31           Standardized
# 32           Standardized
# 33           Standardized
# 34           Standardized

# %%
def num_splits(row):
    num_splits = 1
    if row.test and row.test > 0:
        num_splits += 1
    if row.validation and row.validation > 0:
        num_splits += 1
    if row["name"] == "Flora Incognita":
        num_splits = 0
    return num_splits


ds["num_splits"] = ds.apply(num_splits, axis=1)
ds.head()
# Out:
#                                             name                        short  \
# 0                                  Pl@ntNet-300k                Pl@ntNet-300k
# 1                          Pl@ntNet observations        Pl@ntNet observations
# 2  Pl@ntNet automatically identified occurrences  Pl@ntNet autom. ident. occ.
# 3                                       Flora-On                     Flora-On
# 4                                       iNat2017                     iNat2017
#
#                                          doi  \
# 0     https://doi.org/10.5281/zenodo.5645731
# 1                         DOI10.15468/gtebaa
# 2            https://doi.org/10.15468/mma2ec
# 3                                        NaN
# 4  https://doi.org/10.48550/arXiv.1707.06642
#
#                                                 link  is_available  \
# 0  https://zenodo.org/record/5645731, https://git...          True
# 1  https://www.gbif.org/dataset/7a3679ef-5582-4aa...          True
# 2                    https://doi.org/10.15468/mma2ec          True
# 3                               https://flora-on.pt/          True
# 4  https://github.com/visipedia/inat_comp/tree/ma...          True
#
#   aquisition_protocol  is_composed  num_images  num_images_splits_sum  \
# 0               field        False    306146.0                   True
# 1               field        False   1714213.0                   True
# 2               field        False  12142287.0                   True
# 3                 NaN         True         NaN                   True
# 4               field        False    196613.0                   True
#
#      training  validation     test  num_classes  num_images_full  \
# 0    243916.0     31118.0  31112.0       1081.0             -1.0
# 1   1714213.0         0.0      0.0      15490.0             -1.0
# 2  12142287.0         NaN      NaN      12572.0             -1.0
# 3         NaN         NaN      NaN          NaN              NaN
# 4    158407.0     38206.0      0.0       2101.0         675170.0
#
#    num_classes_full                                additional_metadata   type  \
# 0              -1.0                                              organ  mixed
# 1              -1.0                                         GBIF_a_lot  mixed
# 2              -1.0                                                NaN  mixed
# 3               NaN                                                NaN    NaN
# 4            5089.0  bbox?,kingdom,GBIF,latitude,longitude,date,use...  mixed
#
#                                        super_classes dataset_parts  is_split  \
# 0                                             plants           0.0      True
# 1                                             plants           0.0     False
# 2                                                NaN           0.0      True
# 3                                                NaN           NaN      True
# 4  Plantae,Insecta,Aves,Reptilia,Mammalia,Fungi,A...           0.0      True
#
#   class_imbalance generation_type  \
# 0             1.0  user-generated
# 1               ?  user-generated
# 2             1.0  user-generated
# 3             NaN             NaN
# 4             1.0  user-generated
#
#                                              license  baseline_available  \
# 0                                          CC-BY-4.0                True
# 1                                          CC-BY-4.0               False
# 2                                                NaN               False
# 3                                          CC-BY-4.0               False
# 4  custom:https://github.com/visipedia/inat_comp/...                True
#
#    constantly_updated  is_standardized  DONE  IMPORTANT  \
# 0               False              0.0   1.0        5.0
# 1                True              0.0   1.0        3.0
# 2                True              0.0   1.0        3.0
# 3                True              NaN   0.0        0.0
# 4               False              0.0   1.0        2.0
#
#                                             comments TODO  not_train  \
# 0                                                NaN  NaN    62230.0
# 1                    the big dataset with everything  NaN        0.0
# 2                                                NaN  NaN        NaN
# 3                                                NaN  NaN        NaN
# 4  2017, has plants and other things; train/val i...  NaN    38206.0
#
#   is_standardized_parsed  num_splits
# 0       Not standardized           3
# 1       Not standardized           1
# 2       Not standardized           1
# 3                   None           1
# 4       Not standardized           2

# %%
dsp = ds.dropna(subset=["num_images", "num_classes"], inplace=False)
dsp
# Out:
#                                              name  \
# 0                                   Pl@ntNet-300k
# 1                           Pl@ntNet observations
# 2   Pl@ntNet automatically identified occurrences
# 4                                        iNat2017
# 5                                        iNat2018
# 7                                        iNat2021
# 8                                iNaturalist-300k
# 9         iNaturalist Research-grade Observations
# 10                                    iNaturalist
# 11                        Plant Seedlings Dataset
# 12                Open Plant Phenotyping Database
# 13                                Flora Incognita
# 14                                  PlantCLEF2016
# 15                          PlantCLEF2017-trusted
# 16                    ExpertLifeCLEF 2018-trusted
# 17                                  PlantCLEF2019
# 18                                  PlantCLEF2020
# 19                                  PlantCLEF2021
# 20                                  PlantCLEF2022
# 21                          PlantCLEF2022-trusted
# 22                                         Flavia
# 24                                   Swedish leaf
# 25                                   Plantvillage
# 26                                       UCI Leaf
# 27                                      Leaf snap
# 28                                   Dillen et al
# 29                                  Lorieul et al
# 30                                  Herbarium 255
# 31                                   Herbarium 1K
# 32                                 Herbarium 2019
# 33                                 Herbarium 2020
# 34                                 Herbarium 2021
#
#                               short  \
# 0                     Pl@ntNet-300k
# 1             Pl@ntNet observations
# 2       Pl@ntNet autom. ident. occ.
# 4                          iNat2017
# 5                          iNat2018
# 7                          iNat2021
# 8                  iNaturalist-300k
# 9               iNat Research-grade
# 10                      iNaturalist
# 11          Plant Seedlings Dataset
# 12  Open Plant Phenotyping Database
# 13                  Flora Incognita
# 14                    PlantCLEF2016
# 15                  PlantCLEF2017-t
# 16            ExpertLifeCLEF 2018-t
# 17                    PlantCLEF2019
# 18                    PlantCLEF2020
# 19                    PlantCLEF2021
# 20                    PlantCLEF2022
# 21                  PlantCLEF2022-t
# 22                           Flavia
# 24                     Swedish leaf
# 25                     Plantvillage
# 26                         UCI Leaf
# 27                        Leaf snap
# 28                     Dillen et al
# 29                    Lorieul et al
# 30                    Herbarium 255
# 31                     Herbarium 1K
# 32                   Herbarium 2019
# 33                   Herbarium 2020
# 34                   Herbarium 2021
#
#                                           doi  \
# 0      https://doi.org/10.5281/zenodo.5645731
# 1                          DOI10.15468/gtebaa
# 2             https://doi.org/10.15468/mma2ec
# 4   https://doi.org/10.48550/arXiv.1707.06642
# 5                                         NaN
# 7                                         NaN
# 8                                         NaN
# 9                          DOI10.15468/ab3s5x
# 10                                        NaN
# 11  https://doi.org/10.48550/arXiv.1711.05458
# 12         https://doi.org/10.3390/rs12081246
# 13                                        NaN
# 14                                        NaN
# 15                                        NaN
# 16                                        NaN
# 17                                        NaN
# 18                                        NaN
# 19                                        NaN
# 20                                        NaN
# 21                                        NaN
# 22                                        NaN
# 24                                        NaN
# 25                                        NaN
# 26                                        NaN
# 27                                        NaN
# 28                                        NaN
# 29                                        NaN
# 30                                        NaN
# 31                                        NaN
# 32                                        NaN
# 33                                        NaN
# 34                           arXiv:2105.13808
#
#                                                  link  is_available  \
# 0   https://zenodo.org/record/5645731, https://git...          True
# 1   https://www.gbif.org/dataset/7a3679ef-5582-4aa...          True
# 2                     https://doi.org/10.15468/mma2ec          True
# 4   https://github.com/visipedia/inat_comp/tree/ma...          True
# 5   https://github.com/visipedia/inat_comp/tree/ma...          True
# 7   https://github.com/visipedia/inat_comp/tree/ma...          True
# 8                                                 NaN          True
# 9   https://www.gbif.org/occurrence/charts?dataset...          True
# 10  https://www.inaturalist.org/taxa/47126-Plantae...          True
# 11  https://vision.eng.au.dk/plant-seedlings-dataset/          True
# 12  https://vision.eng.au.dk/open-plant-phenotypin...          True
# 13                                                NaN         False
# 14      https://www.imageclef.org/lifeclef/2016/plant          True
# 15      https://www.imageclef.org/lifeclef/2017/plant          True
# 16                 https://www.imageclef.org/node/231          True
# 17            https://www.imageclef.org/PlantCLEF2019          True
# 18            https://www.imageclef.org/PlantCLEF2020          True
# 19            https://www.imageclef.org/PlantCLEF2021         False
# 20            https://www.imageclef.org/PlantCLEF2022         False
# 21            https://www.imageclef.org/PlantCLEF2022         False
# 22                    https://flavia.sourceforge.ne'/          True
# 24                                                NaN          True
# 25    https://data.mendeley.com/datasets/tywbtsjrjv/1          True
# 26                                                NaN          True
# 27                                                NaN          True
# 28                                                NaN          True
# 29                                                NaN          True
# 30                                                NaN          True
# 31                                                NaN          True
# 32                                                NaN          True
# 33                                                NaN          True
# 34  https://www.kaggle.com/c/herbarium-2021-fgvc8/...          True
#
#    aquisition_protocol  is_composed  num_images  num_images_splits_sum  \
# 0                field        False    306146.0                   True
# 1                field        False   1714213.0                   True
# 2                field        False  12142287.0                   True
# 4                field        False    196613.0                   True
# 5                field        False    127551.0                   True
# 7                field        False   1191412.0                   True
# 8                field        False    526584.0                   True
# 9                field        False  24211423.0                   True
# 10               field        False  57480960.0                   True
# 11                 lab        False      4750.0                   True
# 12                 lab        False      7590.0                   True
# 13               mixed        False   1000000.0                  False
# 14               field         True    115788.0                   True
# 15              field?         True    345714.0                   True
# 16               field         True    327436.0                   True
# 17           field,web         True    437225.0                   True
# 18           lab,field         True    330772.0                   True
# 19           lab,field         True    330772.0                   True
# 20            misc,web         True   4013695.0                   True
# 21            misc,web         True   2942068.0                   True
# 22                 lab        False      1907.0                  False
# 24                 lab         True      1125.0                  False
# 25                 lab         True     54306.0                  False
# 26                 lab         True       443.0                  False
# 27                 lab         True      2130.0                  False
# 28                 lab         True      1900.0                  False
# 29                 lab         True    163233.0                  False
# 30                 lab         True     11071.0                  False
# 31                 lab         True    253733.0                  False
# 32                 lab         True     46000.0                  False
# 33                 lab         True   1170000.0                  False
# 34                 lab         True   2500779.0                   True
#
#       training  validation      test  num_classes  num_images_full  \
# 0     243916.0     31118.0   31112.0       1081.0             -1.0
# 1    1714213.0         0.0       0.0      15490.0             -1.0
# 2   12142287.0         NaN       NaN      12572.0             -1.0
# 4     158407.0     38206.0       0.0       2101.0         675170.0
# 5     118800.0      8751.0       0.0       2917.0         461939.0
# 7    1148702.0     42710.0       0.0       4271.0        2786843.0
# 8     421294.0     52726.0   52564.0        991.0             -1.0
# 9   24211423.0         0.0       0.0     113660.0       62664638.0
# 10  57480960.0         0.0       0.0     147776.0      140663548.0
# 11      4750.0         0.0       0.0         12.0             -1.0
# 12      7590.0         0.0       0.0         47.0             -1.0
# 13         NaN         NaN       NaN       4800.0             -1.0
# 14    113205.0         0.0    2583.0       1000.0             -1.0
# 15    320544.0         0.0   25170.0      10000.0             -1.0
# 16    320544.0         0.0    6892.0      10000.0             -1.0
# 17    434251.0         0.0    2974.0      10000.0             -1.0
# 18    327586.0         0.0    3186.0        997.0             -1.0
# 19    321270.0      6316.0    3186.0        997.0             -1.0
# 20   3958388.0         0.0   55307.0      80000.0             -1.0
# 21   2886761.0         0.0   55307.0      80000.0             -1.0
# 22         NaN         NaN       NaN         32.0             -1.0
# 24         NaN         NaN       NaN         15.0             -1.0
# 25         NaN         NaN       NaN         38.0             -1.0
# 26         NaN         NaN       NaN         40.0             -1.0
# 27         NaN         NaN       NaN         52.0             -1.0
# 28         NaN         NaN       NaN       1580.0             -1.0
# 29         NaN         NaN       NaN       7782.0             -1.0
# 30         NaN         NaN       NaN        255.0             -1.0
# 31         NaN         NaN       NaN       1204.0             -1.0
# 32         NaN         NaN       NaN        680.0             -1.0
# 33         NaN         NaN       NaN      32000.0             -1.0
# 34   2257759.0         0.0  243020.0      64500.0             -1.0
#
#     num_classes_full                                additional_metadata  \
# 0               -1.0                                              organ
# 1               -1.0                                         GBIF_a_lot
# 2               -1.0                                                NaN
# 4             5089.0  bbox?,kingdom,GBIF,latitude,longitude,date,use...
# 5             8142.0  latitude,longitude,date, kingdom, phylum, clas...
# 7            10000.0  latitude,longitude,location_uncertainty,date, ...
# 8               -1.0                                           taxonomy
# 9           332864.0  latitude,longitude,location_uncertainty,date, ...
# 10          429145.0  latitude?,longitude?,location_uncertainty?,dat...
# 11              -1.0                                      segmentation?
# 12              -1.0              growth_condition,bbox,box_id,trial_id
# 13              -1.0                                            6_views
# 14              -1.0                                        plant_organ
# 15              -1.0                                                NaN
# 16              -1.0                                   plant_organ,TODO
# 17              -1.0                                                NaN
# 18              -1.0                                           taxonomy
# 19              -1.0  growth_form,habitat,plant_lifeform,trophic_gui...
# 20              -1.0                                           taxonomy
# 21              -1.0                                           taxonomy
# 22              -1.0                                                NaN
# 24              -1.0                                                NaN
# 25              -1.0                                           diseased
# 26              -1.0                                                NaN
# 27              -1.0                                                NaN
# 28              -1.0                                                NaN
# 29              -1.0                                                NaN
# 30              -1.0                                                NaN
# 31              -1.0                                                NaN
# 32              -1.0                                                NaN
# 33              -1.0                                                NaN
# 34              -1.0  date,license,region_id,name,family,order,insti...
#
#                type                                      super_classes  \
# 0             mixed                                             plants
# 1             mixed                                             plants
# 2             mixed                                                NaN
# 4             mixed  Plantae,Insecta,Aves,Reptilia,Mammalia,Fungi,A...
# 5             mixed  Plantae, Insecta, Aves, Actinopterygii, Fungi,...
# 7             mixed  Plants, Insects, Birds, Fungi, Reptiles, Mamma...
# 8             mixed                                                NaN
# 9             mixed  Animalia, Archaea, Bacteria, Chromista, Fungi,...
# 10            mixed  Animalia, Archaea, Bacteria, Chromista, Fungi,...
# 11     pic_from_top                                             plants
# 12     pic_from_top                                             plants
# 13            mixed                                             plants
# 14            mixed                                             plants
# 15            mixed                                             plants
# 16            mixed                                             plants
# 17            mixed                                             plants
# 18  herbarium,mixed                                             plants
# 19  herbarium,mixed                                             plants
# 20            mixed                                             plants
# 21            mixed                                             plants
# 22             leaf                                             plants
# 24             leaf                                             plants
# 25             leaf                                             plants
# 26             leaf                                             plants
# 27             leaf                                             plants
# 28        herbarium                                             plants
# 29        herbarium                                             plants
# 30        herbarium                                             plants
# 31        herbarium                                             plants
# 32        herbarium                                             plants
# 33        herbarium                                             plants
# 34        herbarium                                             plants
#
#            dataset_parts  is_split class_imbalance     generation_type  \
# 0                    0.0      True             1.0      user-generated
# 1                    0.0     False               ?      user-generated
# 2                    0.0      True             1.0      user-generated
# 4                    0.0      True             1.0      user-generated
# 5                    0.0      True             1.0      user-generated
# 7                    0.0      True             1.0      user-generated
# 8                    NaN      True             1.0      user-generated
# 9                    0.0     False             1.0      user-generated
# 10                   0.0     False             1.0      user-generated
# 11                   0.0     False             0.0                 lab
# 12                   0.0     False             NaN                 lab
# 13                   0.0      True             NaN      user-generated
# 14              plantnet      True             NaN      user-generated
# 15          eol,plantnet      True             NaN               mixed
# 16                   eol      True             1.0               mixed
# 17                   eol      True             NaN               mixed
# 18  eol,plantnet,idigbio      True             NaN  lab,user-generated
# 19  eol,plantnet,idigbio      True             1.0  lab,user-generated
# 20              gbif,eol      True             NaN  lab,user-generated
# 21              gbif,eol      True             NaN  lab,user-generated
# 22                   0.0      True             NaN                 lab
# 24                   0.0      True             NaN                 lab
# 25                   0.0      True             NaN                 lab
# 26                   0.0      True             NaN                 lab
# 27                   0.0      True             NaN                 lab
# 28                   NaN      True             NaN                 NaN
# 29                   NaN      True             NaN                 NaN
# 30                   NaN      True             NaN                 lab
# 31                   NaN      True             NaN                 lab
# 32                   NaN      True             NaN                 lab
# 33                   NaN      True             NaN                 lab
# 34                   0.0      True             1.0                 lab
#
#                                               license  baseline_available  \
# 0                                           CC-BY-4.0                True
# 1                                           CC-BY-4.0               False
# 2                                                 NaN               False
# 4   custom:https://github.com/visipedia/inat_comp/...                True
# 5                                              custom               False
# 7                                              custom               False
# 8                                 CC-0,CC-BY,CC-BY-NC                True
# 9                                 CC-0,CC-BY,CC-BY-NC               False
# 10                                             custom               False
# 11                                           CC-BY-SA               False
# 12                                        CC-BY-NC-SA                True
# 13                                                NaN                True
# 14                                                NaN                True
# 15                                                NaN                True
# 16                                                NaN                True
# 17                                                NaN                True
# 18                                                NaN                True
# 19                                                NaN                True
# 20                                                NaN                True
# 21                                                NaN                True
# 22                                                NaN                True
# 24                                                NaN                True
# 25                                                NaN                True
# 26                                                NaN                True
# 27                                                NaN                True
# 28                                                NaN                True
# 29                                                NaN                True
# 30                                                NaN                True
# 31                                                NaN                True
# 32                                                NaN                True
# 33                                                NaN                True
# 34                        CC-0,CC-BY-SA-2.0,CC-BY-4.0                True
#
#     constantly_updated  is_standardized  DONE  IMPORTANT  \
# 0                False              0.0   1.0        5.0
# 1                 True              0.0   1.0        3.0
# 2                 True              0.0   1.0        3.0
# 4                False              0.0   1.0        2.0
# 5                False              0.0   1.0        2.0
# 7                False              0.0   1.0        2.0
# 8                False              0.0   1.0        5.0
# 9                 True              0.0   1.0        2.0
# 10                True              0.0   1.0        1.0
# 11               False              1.0   1.0        1.0
# 12               False              1.0   1.0        0.0
# 13                True              0.0   0.0        3.0
# 14               False              0.0   1.0        3.0
# 15               False              0.0   1.0        3.0
# 16               False              0.0   1.0        3.0
# 17               False              0.0   1.0        3.0
# 18               False              2.0   1.0        2.0
# 19               False              2.0   1.0        2.0
# 20               False              2.0   1.0        2.0
# 21               False              2.0   1.0        2.0
# 22               False              0.0   1.0        2.0
# 24               False              1.0   NaN        1.0
# 25               False              1.0   NaN        1.0
# 26                True              1.0   NaN        1.0
# 27               False              1.0   NaN        1.0
# 28               False              1.0   NaN        NaN
# 29               False              1.0   NaN        NaN
# 30               False              1.0   NaN        NaN
# 31               False              1.0   NaN        NaN
# 32               False              1.0   NaN        NaN
# 33               False              1.0   NaN        NaN
# 34               False              1.0   1.0        3.0
#
#                                              comments  \
# 0                                                 NaN
# 1                     the big dataset with everything
# 2                                                 NaN
# 4   2017, has plants and other things; train/val i...
# 5                                                 NaN
# 7                          location data can be null;
# 8                                      our dataset ^^
# 9             the 'best' pics from the iNaturalist ds
# 10                                 all of iNaturalist
# 11  ~960 plants, 4750 indiv. pictures in diff grow...
# 12  " 7,590 RGB images with 315,038 plant objects,...
# 13  a lot of papers, conflicting data, no clean re...
# 14                                                NaN
# 15  From https://www.frontiersin.org/articles/10.3...
# 16                              Only 'trusted' images
# 17           It has also train-google and train-bing!
# 18                                                NaN
# 19  321270 herb sheets, 6316 field photos, 354 obs...
# 20  ACTUALLY it has three datasets, for train ther...
# 21  This is only the 'trusted' train+test images, ...
# 22     taking stats from 10.1016/j.compag.2019.01.041
# 24     taking stats from 10.1016/j.compag.2019.01.042
# 25     taking stats from 10.1016/j.compag.2019.01.043
# 26                                                NaN
# 27  Taking stats from https://link.springer.com/ar...
# 28  Taken from table in half-world herbarium paper...
# 29  Taken from table in half-world herbarium paper...
# 30  Taken from table in half-world herbarium paper...
# 31  Taken from table in half-world herbarium paper...
# 32  Taken from table in half-world herbarium paper...
# 33  Taken from table in half-world herbarium paper...
# 34  80/20 train/test split; test split has differe...
#
#                                            TODO  not_train  \
# 0                                           NaN    62230.0
# 1                                           NaN        0.0
# 2                                           NaN        NaN
# 4                                           NaN    38206.0
# 5                                           NaN     8751.0
# 7                                           NaN    42710.0
# 8                                           NaN   105290.0
# 9                                           NaN        0.0
# 10                                          NaN        0.0
# 11                                          NaN        0.0
# 12                                          NaN        0.0
# 13                                          NaN        NaN
# 14                                          NaN     2583.0
# 15                                Add untrusted    25170.0
# 16                      Add untrusted; metadata     6892.0
# 17  Add  train-[goolge/bing] web part+ metadtaa     2974.0
# 18                                          NaN     3186.0
# 19                                          NaN     9502.0
# 20                                          NaN    55307.0
# 21                                          NaN    55307.0
# 22                                          NaN        NaN
# 24                                          NaN        NaN
# 25                                          NaN        NaN
# 26                                          NaN        NaN
# 27              Fill out everything from source        NaN
# 28              Fill out everything from source        NaN
# 29              Fill out everything from source        NaN
# 30              Fill out everything from source        NaN
# 31              Fill out everything from source        NaN
# 32              Fill out everything from source        NaN
# 33              Fill out everything from source        NaN
# 34                                          NaN   243020.0
#
#    is_standardized_parsed  num_splits
# 0        Not standardized           3
# 1        Not standardized           1
# 2        Not standardized           1
# 4        Not standardized           2
# 5        Not standardized           2
# 7        Not standardized           2
# 8        Not standardized           3
# 9        Not standardized           1
# 10       Not standardized           1
# 11           Standardized           1
# 12           Standardized           1
# 13       Not standardized           0
# 14       Not standardized           2
# 15       Not standardized           2
# 16       Not standardized           2
# 17       Not standardized           2
# 18                    N/A           2
# 19                    N/A           3
# 20                    N/A           2
# 21                    N/A           2
# 22       Not standardized           1
# 24           Standardized           1
# 25           Standardized           1
# 26           Standardized           1
# 27           Standardized           1
# 28           Standardized           1
# 29           Standardized           1
# 30           Standardized           1
# 31           Standardized           1
# 32           Standardized           1
# 33           Standardized           1
# 34           Standardized           2

# %%
len(ds[ds.DONE == 1])
# Out:
# 22

# %%
import matplotlib.pyplot as plt
import adjustText

sns.set_style("white")

# %%
sns.set_context("notebook", font_scale=1.25)
ax = sns.scatterplot(
    data=dsp,
    x="num_images",
    y="num_classes",
    # style="is_available",
    # hue="type",
    hue="aquisition_protocol",
    s=200,
    # marker="$x$",
    marker="X",
)
ax.set(xscale="log", yscale="log")
ax.figure.set_size_inches(12, 12)

texts = list()
for i, row in dsp.iterrows():
    txt = plt.text(
        row.num_images,
        row.num_classes,
        row["name"],
        ha="center",
        va="center",
        # color="black" if row["is_available"] else "red",
    )
    texts.append(txt)

adjustText.adjust_text(
    texts,
    arrowprops=dict(
        arrowstyle="->",
        # arrowstyle="-|>",
        color="red",
        lw=1.5,
    ),
)

ax.set_title("Some datasets, in red: not easily downloadable")
# Out:
# Text(0.5, 1.0, 'Some datasets, in red: not easily downloadable')

# %%
from matplotlib.markers import MarkerStyle

# %%
data = dsp
ax = sns.scatterplot(
    data=data,
    x="num_images",
    y="num_classes",
    style="type",
    hue="num_splits",
    # hue="type",
    # hue="aquisition_protocol",
    s=300,
    palette="flare",
    markers={
        "mixed": MarkerStyle("8"),
        "pic_from_top": MarkerStyle("P"),
        "herbarium": MarkerStyle("X"),
        "herbarium,mixed": MarkerStyle("p"),
        "leaf": MarkerStyle("d"),
    },
    # marker="X"
    # marker="$x$",
    # marker=MarkerStyle("*"),
    # marker=MarkerStyle("x"),
    # style="is_available",
    # markers={True: MarkerStyle("x"), False: MarkerStyle("+")},
    # legend="full",
)
ax.set(xscale="log", yscale="log")
ax.figure.set_size_inches(19, 12)

texts = list()
for i, row in data.iterrows():
    txt = plt.text(
        row.num_images,
        row.num_classes,
        row["name"],
        ha="center",
        va="center",
        color="black" if row["is_available"] else "red",
    )
    texts.append(txt)

adjustText.adjust_text(
    texts,
    expand=(1.5, 1.5),
    arrowprops=dict(
        arrowstyle="->",
        # arrowstyle="-|>",
        color="red",
        lw=1.5,
    ),
)

ax.set_title("Some datasets, in red: not easily downloadable")
sns.move_legend(ax, "lower right")
ax.legend(fontsize=10, markerscale=2)

# h, l = ax.get_legend_handles_labels()
# l1 = ax.legend(
#     h[: int(len(h) / 2)], l[: int(len(l) / 2)], loc="lower right", title="t1"
# )
# l2 = ax.legend(
#     h[int(len(h) / 2) :], l[int(len(l) / 2) :], loc="center right", title="t2"
# )
# ax.add_artist(l1)  # we need this because the 2nd call to legend() erases the first

# %%
# Delete the not-trusted 2022 dataset
dsp.drop(index=20, inplace=True)
# Out:
# /tmp/ipykernel_2359140/2556983625.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dsp.drop(index=20, inplace=True)

# %%
# Flora Incognita
dsp.loc[13, "num_splits"] = "N/A"
# Out:
# /tmp/ipykernel_2359140/3609471819.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dsp.loc[13, "num_splits"] = "N/A"

# %%
sns.set_context("paper")
data = dsp[dsp.num_images > 80_000]
data = data[data["type"] != "herbarium"]
data = data[data["name"] != "Flora Incognita"]

ax = sns.scatterplot(
    data=data,
    x="num_images",
    y="num_classes",
    style="is_standardized_parsed",
    hue="num_splits",
    # hue="type",
    # hue="aquisition_protocol",
    s=100,
    # palette="flare",
    palette=sns.color_palette("tab10", 3),
    # palette="bright",
    # palette=sns.color_palette("rainbow",3),
    markers={
        "Standardized": MarkerStyle("X"),
        "Not standardized": MarkerStyle("o"),
        "N/A": MarkerStyle("v"),
    },
    # marker="X"
    # marker="$x$",
    # marker=MarkerStyle("*"),
    # marker=MarkerStyle("x"),
    # style="is_available",
    # markers={True: MarkerStyle("x"), False: MarkerStyle("+")},
    # legend="full",
)
ax.set(xscale="log", yscale="log")
ax.figure.set_size_inches(19, 12)
ax.figure.set_size_inches(19, 8)
ax.figure.set_size_inches(19, 6)
ax.figure.set_size_inches(10, 5)
ax.figure.set_size_inches(15, 6)
ax.figure.set_size_inches(14, 4)
ax.figure.set_size_inches(11, 4)
ax.figure.set_size_inches(14.5, 3.8)

ax.set_ylabel("Number of classes/species")
ax.set_xlabel("Number of images")

texts = list()
for i, row in data.iterrows():
    txt = plt.text(
        row.num_images,
        row.num_classes,
        # row["name"].upper(),
        row["name"],
        # row["short"],
        ha="center",
        va="center",
        # va="bottom" if row["is_available"] else "center",
        # ha="center" if row["is_available"] else "right",
        color="black" if row["is_available"] else "red",
        fontsize=12,
        fontweight="normal" if row["name"] != "iNaturalist-300k" else "bold",
    )
    texts.append(txt)

# Increase lims so there's place for text
left, right = ax.get_xlim()
ax.set_xlim(left - 15000, right + 100000000)
bottom, top = ax.get_ylim()
ax.set_ylim(bottom - 200, top + 10000)


adjustText.adjust_text(
    texts,
    # expand=(1.5, 2.0),
    # expand=(1.4, 1.4),
    # force_explode=(0.01, 0.03),
    avoid_self=True,
    force_text=(0.2, 0.7),
    force_static=(0.2, 0.4),
    min_arrow_len=10,
    time_lim=1.0,
    arrowprops=dict(
        # arrowstyle="->",
        arrowstyle="-|>",
        color="red",
        # lw=1.5,
    ),
)

# Increase lims AGAIN, now that the text is set, to create pretty white margins around them
bottom, top = ax.get_ylim()
ax.set_ylim(bottom, top + 16000)
left, right = ax.get_xlim()
ax.set_xlim(left - 8000, right + 30140000)

# ax.set_title("Some datasets, in red: not publicly available")
# sns.move_legend(ax, "lower right")
ax.legend(fontsize=8, markerscale=2, loc="lower right")

# order = [1, 2, 0, 3]
# handles, labels = plt.gca().get_legend_handles_labels()
# plt.legend([handles[i] for i in order], [labels[i] for i in order])

ax.figure.savefig("dataset_sizes_plot_v2.png", bbox_inches="tight")

# %%
sns.set_context("paper")
data = dsp[dsp.num_images > 80_000]
data = data[data["type"] != "herbarium"]
data = data[data["name"] != "Flora Incognita"]

ax = sns.scatterplot(
    data=data,
    x="num_images",
    y="num_classes",
    # style="is_standardized_parsed",
    hue="num_splits",
    style="is_available",
    # hue="type",
    # hue="aquisition_protocol",
    s=100,
    # palette="flare",
    palette=sns.color_palette("tab10", 3),
    # palette="bright",
    # palette=sns.color_palette("rainbow",3),
    markers={
        False: MarkerStyle("X"),
        True: MarkerStyle("o"),
    },
    # marker="X"
    # marker="$x$",
    # marker=MarkerStyle("*"),
    # marker=MarkerStyle("x"),
    # style="is_available",
    # markers={True: MarkerStyle("x"), False: MarkerStyle("+")},
    # legend="full",
)
ax.set(xscale="log", yscale="log")
ax.figure.set_size_inches(19, 12)
ax.figure.set_size_inches(19, 8)
ax.figure.set_size_inches(19, 6)
ax.figure.set_size_inches(10, 5)
ax.figure.set_size_inches(15, 6)
ax.figure.set_size_inches(14, 4)
ax.figure.set_size_inches(11, 4)
ax.figure.set_size_inches(14.5, 3.8)

ax.set_ylabel("Number of classes/species")
ax.set_xlabel("Number of images")

texts = list()
for i, row in data.iterrows():
    txt = plt.text(
        row.num_images,
        row.num_classes - (10 if row["name"] == "PlantCLEF2020" else 0),
        # row["name"].upper(),
        row["name"],
        # row["short"],
        ha="center",
        va="center",
        # va="bottom" if row["is_available"] else "center",
        # ha="center" if row["is_available"] else "right",
        color="black" if row["is_available"] else "red",
        fontsize=12,
        fontweight="normal" if row["name"] != "iNaturalist-300k" else "bold",
    )
    texts.append(txt)

# Increase lims so there's place for text
left, right = ax.get_xlim()
ax.set_xlim(left - 15000, right + 100000000)
bottom, top = ax.get_ylim()
ax.set_ylim(bottom - 200, top + 10000)


adjustText.adjust_text(
    texts,
    # expand=(1.5, 2.0),
    # expand=(1.4, 1.4),
    # force_explode=(0.01, 0.03),
    avoid_self=True,
    force_text=(0.2, 0.7),
    force_static=(0.2, 0.4),
    min_arrow_len=10,
    time_lim=1.0,
    arrowprops=dict(
        # arrowstyle="->",
        arrowstyle="-|>",
        color="red",
        # lw=1.5,
    ),
)

# Increase lims AGAIN, now that the text is set, to create pretty white margins around them
bottom, top = ax.get_ylim()
ax.set_ylim(bottom, top + 16000)
left, right = ax.get_xlim()
ax.set_xlim(left - 8000, right + 30140000)

# ax.set_title("Some datasets, in red: not publicly available")
# sns.move_legend(ax, "lower right")
ax.legend(fontsize=8, markerscale=2, loc="lower right")

# order = [1, 2, 0, 3]
# handles, labels = plt.gca().get_legend_handles_labels()
# plt.legend([handles[i] for i in order], [labels[i] for i in order])

ax.figure.savefig("dataset_sizes_plot_v2.png", bbox_inches="tight")

# %%
# data = dsp[dsp.num_images > 80_000]

small_cols = [
    # "name",
    "short",
    # "is_available",
    # "is_standardized_parsed",
    "num_classes",
    "training",
    "validation",
    "test",
]
small_data = data[data["type"] != "herbarium"][small_cols]
"""
small_data.is_standardized_parsed = small_data.is_standardized_parsed.replace(
    "Standardized", "Yes"
)
small_data.is_standardized_parsed = small_data.is_standardized_parsed.replace(
    "Not standardized", "No"
)
small_data.is_standardized_parsed = small_data.is_standardized_parsed.replace(
    "N/A", "N/A"
)
"""

"""
small_data[["training", "validation", "test"]] = small_data[
    ["training", "validation", "test"]
].astype("int32", errors="ignore")
small_data

small_data[["training", "validation", "test"]] = small_data[
    ["training", "validation", "test"]
].convert_dtypes(infer_objects=False)
"""
small_data
# Out:
#                           short  num_classes    training  validation     test
# 0                 Pl@ntNet-300k       1081.0    243916.0     31118.0  31112.0
# 1         Pl@ntNet observations      15490.0   1714213.0         0.0      0.0
# 2   Pl@ntNet autom. ident. occ.      12572.0  12142287.0         NaN      NaN
# 4                      iNat2017       2101.0    158407.0     38206.0      0.0
# 5                      iNat2018       2917.0    118800.0      8751.0      0.0
# 7                      iNat2021       4271.0   1148702.0     42710.0      0.0
# 8              iNaturalist-300k        991.0    421294.0     52726.0  52564.0
# 9           iNat Research-grade     113660.0  24211423.0         0.0      0.0
# 10                  iNaturalist     147776.0  57480960.0         0.0      0.0
# 14                PlantCLEF2016       1000.0    113205.0         0.0   2583.0
# 15              PlantCLEF2017-t      10000.0    320544.0         0.0  25170.0
# 16        ExpertLifeCLEF 2018-t      10000.0    320544.0         0.0   6892.0
# 17                PlantCLEF2019      10000.0    434251.0         0.0   2974.0
# 18                PlantCLEF2020        997.0    327586.0         0.0   3186.0
# 19                PlantCLEF2021        997.0    321270.0      6316.0   3186.0
# 21              PlantCLEF2022-t      80000.0   2886761.0         0.0  55307.0

# %%
tvtn = ["training", "validation", "test", "num_classes"]
small_data[tvtn] = small_data[tvtn].applymap(lambda x: f"{x:0,.0f}")

# small_data["name"] = small_data["name"].replace("iNaturalist", "iNat", regex=True)
# small_data["name"] = small_data["name"].replace("trusted", "t", regex=True)
small_data
# Out:
#                           short num_classes    training validation    test
# 0                 Pl@ntNet-300k       1,081     243,916     31,118  31,112
# 1         Pl@ntNet observations      15,490   1,714,213          0       0
# 2   Pl@ntNet autom. ident. occ.      12,572  12,142,287        nan     nan
# 4                      iNat2017       2,101     158,407     38,206       0
# 5                      iNat2018       2,917     118,800      8,751       0
# 7                      iNat2021       4,271   1,148,702     42,710       0
# 8              iNaturalist-300k         991     421,294     52,726  52,564
# 9           iNat Research-grade     113,660  24,211,423          0       0
# 10                  iNaturalist     147,776  57,480,960          0       0
# 14                PlantCLEF2016       1,000     113,205          0   2,583
# 15              PlantCLEF2017-t      10,000     320,544          0  25,170
# 16        ExpertLifeCLEF 2018-t      10,000     320,544          0   6,892
# 17                PlantCLEF2019      10,000     434,251          0   2,974
# 18                PlantCLEF2020         997     327,586          0   3,186
# 19                PlantCLEF2021         997     321,270      6,316   3,186
# 21              PlantCLEF2022-t      80,000   2,886,761          0  55,307

# %%
small_data[tvtn] = small_data[tvtn].replace(np.nan, "-")
small_data[tvtn] = small_data[tvtn].replace("0", "-")

# small_data[["training", "validation", "test"]].replace(np.nan, "-", inplace=True)
small_data[tvtn] = small_data[tvtn].replace("nan", "-")

small_data
# Out:
#                           short num_classes    training validation    test
# 0                 Pl@ntNet-300k       1,081     243,916     31,118  31,112
# 1         Pl@ntNet observations      15,490   1,714,213          -       -
# 2   Pl@ntNet autom. ident. occ.      12,572  12,142,287          -       -
# 4                      iNat2017       2,101     158,407     38,206       -
# 5                      iNat2018       2,917     118,800      8,751       -
# 7                      iNat2021       4,271   1,148,702     42,710       -
# 8              iNaturalist-300k         991     421,294     52,726  52,564
# 9           iNat Research-grade     113,660  24,211,423          -       -
# 10                  iNaturalist     147,776  57,480,960          -       -
# 14                PlantCLEF2016       1,000     113,205          -   2,583
# 15              PlantCLEF2017-t      10,000     320,544          -  25,170
# 16        ExpertLifeCLEF 2018-t      10,000     320,544          -   6,892
# 17                PlantCLEF2019      10,000     434,251          -   2,974
# 18                PlantCLEF2020         997     327,586          -   3,186
# 19                PlantCLEF2021         997     321,270      6,316   3,186
# 21              PlantCLEF2022-t      80,000   2,886,761          -  55,307

# %%
# inaturalist-full is, well, not suitable
small_data.drop(index=10, inplace=True)

# 2022 as not available
small_data.drop(index=21, inplace=True)
# small_data.drop(index=20, inplace=True)

# Autom. ident. occ
small_data.drop(index=2, inplace=True)

# Herbaria
# small_data.drop(index=28, inplace=True)
# small_data.drop(index=30, inplace=True)
# small_data.drop(index=32, inplace=True)
# small_data.drop(index=33, inplace=True)

# Flora Inc.
# small_data.drop(index=13, inplace=True)

# 20,21
# small_data.drop(index=15, inplace=True)
# small_data.drop(index=17, inplace=True)
small_data.drop(index=18, inplace=True)

small_data
# Out:
#                     short num_classes    training validation    test
# 0           Pl@ntNet-300k       1,081     243,916     31,118  31,112
# 1   Pl@ntNet observations      15,490   1,714,213          -       -
# 4                iNat2017       2,101     158,407     38,206       -
# 5                iNat2018       2,917     118,800      8,751       -
# 7                iNat2021       4,271   1,148,702     42,710       -
# 8        iNaturalist-300k         991     421,294     52,726  52,564
# 9     iNat Research-grade     113,660  24,211,423          -       -
# 14          PlantCLEF2016       1,000     113,205          -   2,583
# 15        PlantCLEF2017-t      10,000     320,544          -  25,170
# 16  ExpertLifeCLEF 2018-t      10,000     320,544          -   6,892
# 17          PlantCLEF2019      10,000     434,251          -   2,974
# 19          PlantCLEF2021         997     321,270      6,316   3,186

# %%
small_data
# Out:
#                     short num_classes    training validation    test
# 0           Pl@ntNet-300k       1,081     243,916     31,118  31,112
# 1   Pl@ntNet observations      15,490   1,714,213          -       -
# 4                iNat2017       2,101     158,407     38,206       -
# 5                iNat2018       2,917     118,800      8,751       -
# 7                iNat2021       4,271   1,148,702     42,710       -
# 8        iNaturalist-300k         991     421,294     52,726  52,564
# 9     iNat Research-grade     113,660  24,211,423          -       -
# 14          PlantCLEF2016       1,000     113,205          -   2,583
# 15        PlantCLEF2017-t      10,000     320,544          -  25,170
# 16  ExpertLifeCLEF 2018-t      10,000     320,544          -   6,892
# 17          PlantCLEF2019      10,000     434,251          -   2,974
# 19          PlantCLEF2021         997     321,270      6,316   3,186

# %%
print(
    tabulate.tabulate(
        small_data,
        tablefmt="latex",
        headers=small_data.columns,
        # stralign="right",
        showindex=False,
    )
)
# print(tabulate.tabulate(small_data, floatfmt=".0f"))
# Out:
# \begin{tabular}{lllll}
# \hline
#  short                 & num\_classes   & training   & validation   & test   \\
# \hline
#  Pl@ntNet-300k         & 1,081         & 243,916    & 31,118       & 31,112 \\
#  Pl@ntNet observations & 15,490        & 1,714,213  & -            & -      \\
#  iNat2017              & 2,101         & 158,407    & 38,206       & -      \\
#  iNat2018              & 2,917         & 118,800    & 8,751        & -      \\
#  iNat2021              & 4,271         & 1,148,702  & 42,710       & -      \\
#  iNaturalist-300k      & 991           & 421,294    & 52,726       & 52,564 \\
#  iNat Research-grade   & 113,660       & 24,211,423 & -            & -      \\
#  PlantCLEF2016         & 1,000         & 113,205    & -            & 2,583  \\
#  PlantCLEF2017-t       & 10,000        & 320,544    & -            & 25,170 \\
#  ExpertLifeCLEF 2018-t & 10,000        & 320,544    & -            & 6,892  \\
#  PlantCLEF2019         & 10,000        & 434,251    & -            & 2,974  \\
#  PlantCLEF2021         & 997           & 321,270    & 6,316        & 3,186  \\
# \hline
# \end{tabular}
